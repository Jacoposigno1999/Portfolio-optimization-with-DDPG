# %%
from numpy.random import randn
import numpy as np
from itertools import count
from collections import namedtuple
from torch.utils.tensorboard import SummaryWriter
import os
import seaborn as sns
#import args
from scipy import stats
import pandas as pd
from datetime import datetime, timedelta
import random
from collections import namedtuple
import torch as pt
import statistics
import csv

#from replay_memory import Memory, Transition
#from ounoise import OrnsteinUhlenbeckActionNoise as noise
#from market_env import trade_env
#import market_env

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import matplotlib.pyplot as plt
import random
from functools import reduce
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=DeprecationWarning)

# %%
from google.colab import drive
drive.mount('/content/drive')
os.chdir("/content/drive/MyDrive/TESI/Codice")
os.getcwd()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/drive/MyDrive/TESI/Codice'

# %%
# !pip install stockstats
from preprocessors_3 import FeatureEngineer#,moving_average
# Out:
# Collecting stockstats
#   Downloading stockstats-0.6.2-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from stockstats) (1.23.5)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from stockstats) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->stockstats) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->stockstats) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.24.2->stockstats) (1.16.0)
# Installing collected packages: stockstats
# Successfully installed stockstats-0.6.2

# %%
path = '/content/drive/MyDrive/TESI'
writer = SummaryWriter(path + '/tensor')


for file in os.listdir(path + '/tensor'):
    file = os.path.join(path + '/tensor',file)
    os.remove(file)

# %%
capacity=1000000
class Replay_buffer():
    '''
    Expects tuples of (state, next_state, action, reward, done)
    '''
    def __init__(self, max_size=capacity):
        """Create Replay buffer.
        Parameters
        ----------
        size: int
            Max number of transitions to store in the buffer. When the buffer
            overflows the old memories are dropped.
        """
        self.storage = []
        self.max_size = max_size
        self.ptr = 0

    def push(self, data):
        if len(self.storage) == self.max_size:
            self.storage[int(self.ptr)] = data
            self.ptr = (self.ptr + 1) % self.max_size
        else:
            self.storage.append(data)

    def sample(self, batch_size):
        """Sample a batch of experiences.
        Parameters
        ----------
        batch_size: int
            How many transitions to sample.
        Returns
        -------
        state: np.array
            batch of state or observations
        action: np.array
            batch of actions executed given a state
        reward: np.array
            rewards received as results of executing action
        next_state: np.array
            next state next state or observations seen after executing action
        done: np.array
            done[i] = 1 if executing ation[i] resulted in
            the end of an episode and 0 otherwise.
        """
        ind = np.random.randint(0, len(self.storage), size=batch_size)
        state, next_state, action, reward, done = [], [], [], [], []

        for i in ind:
            st, n_st, act, rew, dn = self.storage[i]
            state.append(np.array(st, copy=False))
            next_state.append(np.array(n_st, copy=False))
            action.append(np.array(act, copy=False))
            reward.append(np.array(rew, copy=False))
            done.append(np.array(dn, copy=False))

        return np.array(state), np.array(next_state), np.array(action), np.array(reward).reshape(-1, 1), np.array(done).reshape(-1, 1)



#ALTRA OPZIONE DI REPLAY BUFFER
Transition = namedtuple('Transition', ('state','action', 'mask', 'utility', 'next_state'))


class Memory(object):

    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        """Saves a transition."""
        if len(self.memory) < self.capacity:
            self.memory.append(None) #None values are placeholders that allow the replay memory to be initialized without having to worry about the actual contents of the memory at the start.
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %% [markdown]
# # **Actor-Critic Neural Network**
#
# The code defines two neural network models, an Actor and a Critic.
#
# **Input to Actor model**: Environment state
# **Output of the Actor model**: an action that has a continuous value.
#
# **Input to Critic model**: Environment state and action
# **Output of the Critic model**: A Q-value that is the expected total reward for the current state-action pair.

# %%
class Actor(nn.Module):
    def __init__(self, n_states, action_dim, hidden1): #n_states --> should be the number of inputs passed --> num_inputs = ((action_space - 1) * state_space) = 60
        super(Actor, self).__init__()
        self.affine1 = nn.Linear(n_states, hidden1)
        self.ln1 = nn.LayerNorm(hidden1)

        self.affine2 = nn.Linear(hidden1, hidden1)
        self.ln2 = nn.LayerNorm(hidden1)

        self.value = nn.Linear(hidden1, action_dim)

    def forward(self, x):
        x = self.affine1(x)
        x = self.ln1(x)
        x = F.relu(x)

        x = self.affine2(x)
        x = self.ln2(x)
        actions = F.softmax(self.value(x), dim=-1)

        return actions


'''
class Critic(nn.Module):
    def __init__(self, n_states, action_dim, hidden2):
        super(Critic, self).__init__()
        print(f'N_states citric: {n_states}, action_dim citric: {action_dim}')
        self.affine1 = nn.Linear(n_states + action_dim, hidden2)
        self.ln1 = nn.LayerNorm(hidden2)

        self.affine2 = nn.Linear(hidden2, hidden2)
        self.ln2 = nn.LayerNorm(hidden2)

        self.value = nn.Linear(hidden2, 1)

    def forward(self, x, actions):
        x = self.affine1(x)
        x = self.ln1(x)
        x = F.relu(x)

        #x = torch.cat((x, actions), 1)
        x = self.affine2(x)
        x = self.ln2(x)
        q_value = self.value(F.relu(x))

        return q_value

'''

#second citric option

class Critic(nn.Module):
    def __init__(self, n_states, action_dim, hidden2):
        super(Critic, self).__init__()
        self.affine1 = nn.Linear(n_states, hidden2)
        self.ln1 = nn.LayerNorm(hidden2)

        self.affine2 = nn.Linear(action_dim + hidden2, hidden2)
        self.ln2 = nn.LayerNorm(hidden2)

        self.value = nn.Linear(hidden2, 1)

    def forward(self, x, actions):
        x = self.affine1(x)
        x = self.ln1(x)
        x = F.relu(x)

        x = torch.cat((x, actions), 1)
        x = self.affine2(x)
        x = self.ln2(x)
        q_value = self.value(F.relu(x))

        return q_value

# %% [markdown]
# # Envirionment

# %%
folder_path = '/content/drive/MyDrive/TESI/Codice'

# %%
def get_return(df, var):
    df['G1'] = df[var].pct_change(1)
    df['N1'] = np.log(df[var].pct_change(1)+1) #dayly log return

    df['G5'] = df[var].pct_change(5)
    df['N5'] = np.log(df[var].pct_change(5)+1)# 5 day log return

    df['G1_mon'] = df[var].pct_change(25)
    df['N1_mon'] = np.log(df[var].pct_change(25)+1)

    df['G6_mon'] = df[var].pct_change(125)
    df['N6_mon'] = np.log(df[var].pct_change(125)+1)

    df['G1_yr'] = df[var].pct_change(250)
    #df['N1_yr'] = np.log(df[var].pct_change(250)+1)

    df['G2_yr'] = df[var].pct_change(500)
    #df['N2_yr'] = np.log(df[var].pct_change(500)+1)

#     df['MA2'] = df[var].rolling(2, min_periods=2).mean()
    #df['MA4'] = df[var].rolling(4, min_periods=4).mean()
    return df

def get_return_std(df, y):
    df['R1_std'] = df[y].rolling(125, min_periods=125).std()
    df['R2_std'] = df[y].rolling(250, min_periods=250).std()
    return df

def get_state(df):
    df = get_return(df, 'adj close')
    df = get_return_std(df, 'N1')
    # keep states needed
    df = df[['Date', 'adj close', 'volume'] + fe.tech_indicator_list  + list(df.filter(regex='^N|^R|^MA'))]
    df = df.rename(columns={'adj close': 'close'})
    return df



def get_training_set(dic):
    train = {}
    for key, value in dic.items():
        train[key] = value.loc[(value.Date >= start_date) & (value.Date < end_date)].reset_index(drop=True)
        train[key] = get_state(train[key])
        #train[key] = train[key].iloc[500:].reset_index(drop=True)
        train[key]['weekday'] = pd.to_datetime(train[key].Date).dt.dayofweek
        train[key] = train[key].dropna().reset_index(drop=True)
    return train

# save 500 days to calculate 2-year return
def get_test_set(dic):
    test = {}
    for key, value in dic.items():
        test[key] = value.iloc[int(value.index[value.Date==end_date].values - 500):].reset_index(drop=True)
        test[key] = get_state(test[key])
        test[key] = test[key].iloc[500:].reset_index(drop=True)
        test[key]['weekday'] = pd.to_datetime(test[key].Date).dt.dayofweek
    return test

# %%
#for key, value in stock_d.items():
  #print (key)
  #print(stock_d[key])

# %%
def get_holidays(df):
    df['Date'] = pd.to_datetime(df['Date'])
    date = df['Date'].min()
    end_date = df['Date'].max()
    holidays = []
    while date <= end_date:
        if date.weekday() <= 5:
          if date not in list(df.Date):
            holidays.append(date.strftime("%Y-%m-%d"))
        date += timedelta(days=1)
    df['Date'] = df['Date'].astype(str)
    return holidays

# %%
def baseline_portfolio(dic, start_date, worth, end_date):
  stock_quantity = {}
  stock_number = len(dic)-1
  for key, df in dic.items():
    if key != '^GSPC':
      stock_amount = worth / stock_number
      sotck_value = df[df['Date'] == start_date]['close'].item()

      stock_quantity[key] = (stock_amount/sotck_value)

  portfolio = pd.DataFrame(columns=['Date', 'Value'])
  portfolio = portfolio.append({'Date': start_date, 'Value': worth}, ignore_index=True)



  portfolio_value = 0
  date = start_date

  while date != end_date:

    for key, df in dic.items():
      if key != '^GSPC':
        portfolio_value += stock_quantity[key] * df[df['Date'] == date]['close'].item()
    portfolio = portfolio.append({'Date': date, 'Value': portfolio_value}, ignore_index=True)
    portfolio_value = 0
    date = add_one_trade_day(date)

  return portfolio

# %%
# %%capture
#load stocks

data_folder = '/content/drive/MyDrive/TESI/00_Raw_Data'
os.chdir(data_folder)
stock = [x.replace('.csv', '') for x in os.listdir(data_folder)]
stock = [x for x in stock if x!='TSLA' and x!='AMZN' and x!='KO' and x!='MSFT' and x != "XOM"] #used stocks --> ['AAPL, XOM, UNH, PG, JPM]
# stock = ['SPX', 'BA', 'MS']
tables = [pd.read_csv(x + ".csv", skiprows= range(1, 1901) ) for x in stock ]
stock_d = dict(zip(stock, tables)) # line_plot(stock_d['SPX'], 'close', 'SPX')

#FeatureEngineer on loaded data
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    use_turbulence=False,
                    user_defined_feature = False)

for key, df in stock_d.items():
    stock_d[key]= fe.preprocess_data(stock_d[key])
    stock_d[key].rename(columns={'date': 'Date'}, inplace=True)



# env para
start_date = max([value.Date.min() for key, value in stock_d.items()])
end_date = '2022-01-05'
worth = 20000
bottom_line = worth * 0.9 #episode stop if we loose more than this amount
cycle = 7 #is the max steps of each episode
memory = Memory(100000)

# get train and test
train = get_training_set(stock_d)
test = get_test_set(stock_d)
holidays = get_holidays(train['^GSPC']) + get_holidays(test['^GSPC'])
#train = get_holiday_dummy(train)
#test = get_holiday_dummy(test)
train['^GSPC']['close'] = train['^GSPC']['close']/10 # I think is a sort of re-scaling
test['^GSPC']['close'] = test['^GSPC']['close']/10 # I think is a sort of re-scaling


def concat(x,y): return pd.concat([x,y], axis=0).reset_index(drop=True)

def get_info(env, date): #return information for each stock for a specific day
    info_matrix = []
    info_SPX = []
    for key, df in env.items():
        if key == '^GSPC':
          df['stock'] = key
          a = df.loc[df.Date == date]
          info_SPX += [a]
        else:
          df['stock'] = key
          b = df.loc[df.Date == date] #a that only contains rows where the date column in df matches the specified date value
          info_matrix += [b]
    return reduce((lambda x, y: concat(x,y)), info_matrix),reduce((lambda x, y: concat(x,y)), info_SPX)# combine multiple DataFrames in a list called info_matrix into a single DataFrame.

def fraction_power(x, n):
    if 0<=x: return x**(1./n)
    return -(-x)**(1./n)


def add_days(date, days):
    new_datetime = datetime.strptime(date, "%Y-%m-%d") + timedelta(days)
    new_date = new_datetime.strftime("%Y-%m-%d")
    return new_date



def add_one_trade_day(date):
    date = add_days(date, 1)
    while (datetime.strptime(date, "%Y-%m-%d").weekday()>=5) or (date in holidays):
        date = add_days(date, 1)
    return date




# this env does not have interest rate or mutual fund, and has no transaction cost
class trade_env():
    def __init__(self, env, worth, cycle, rho):
        self.env = env
        self.cycle = cycle
        self.rho = rho
        self.action_space = len(env.keys()) # Is the number of stocks  + 1 for holding cahs (the +1 is given by the '^GSPC' values in the env )
        self.state_space = len(env['^GSPC'].columns) - 1 # minus 2 to not consider column "stock" and "date" !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        self.end_date = env['^GSPC'].Date.max()
        self.reset(worth)

    def step(self, action):

         # normalize to sum of 1
        action = (np.array(action) - np.array(action).min()) / (np.array(action) - np.array(action).min()).sum()

        #print('&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&')
        #print(f'action: {action}, action sum: {np.sum(action)}')
        #print('&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&')

        # today
        last_worth = self.worth
        last_SPX_worth = self.SPX_worth
        stock_info, SPX_info = get_info(self.env, self.date)

        SPX_price = SPX_info.loc[SPX_info.stock == '^GSPC'].close.item()


        SPX_share = self.SPX_worth // SPX_price #calculates the number of SPX shares that the agent can purchase with its current SPX worth
        SPX_changes = self.SPX_worth % SPX_price #This line calculates the remaining amount of SPX worth left after purchasing the calculated number of SPX shares (SPX_share)

        self.prices = np.append([1], stock_info.close.to_numpy())  # 1 is the opportunity cost of holding cash (This expression creates a new NumPy array and appends the value 1 to the beginning of the array.)
        #print('&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&')
        #print(f'self.prices {self.prices}')
        #print(f'self.worth: {self.worth}')
        #print(f'action: {action}')
        #print('&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&')
        self.share = self.worth * action // self.prices #tell how many share of each stock the agent is buying
        changes = (self.worth * action % self.prices)[1: self.action_space]
        self.share[0] = self.share[0] + np.sum(changes) # changes go to cash, i.e., share[0]

        # next day

        self.date = add_one_trade_day(self.date)
        new_stock_info, new_SPX_info = get_info(self.env, self.date)

        SPX_new_price = new_SPX_info.close.item()
        self.SPX_worth = SPX_share * SPX_new_price + SPX_changes
        SPX_reward = self.SPX_worth - last_SPX_worth
        #print(f"-====================-SPX REWARD UPDATE NUMBER{t}-===================================-")
        #print(f'last_SPX_worth: {last_SPX_worth}')
        #print(f'self.SPX_worth: {self.SPX_worth}')
        #print(f'SPX_reward: {SPX_reward}')

        new_prices = np.append([1], new_stock_info.close.to_numpy())
        self.worth  = np.sum(self.share * new_prices)

        # reality
        state = np.array(new_stock_info.drop(['Date', 'stock'],axis=1))
        reward = self.worth - last_worth
        '''
        print(f"------------------ REWARD UPDATE NUMBER{t}---------------------------------------")
        print(f'self.share: {self.share}')
        print(f'new_prices: {new_prices}')
        print(f'last_worth: {last_worth}')
        print(f'self.worth: {self.worth}')
        print(f'reward: {reward}')'''
        utility = fraction_power(reward, self.rho)
        gone = datetime.strptime(self.date, "%Y-%m-%d") - datetime.strptime(self.initial_date, "%Y-%m-%d") #how many days passed since the beginning

        if (self.worth < bottom_line) or (gone.days > self.cycle) or (self.date == self.end_date): #if one of this condition is meet, stop it, and take another decision
            done = True                                                                            #es. if cycle = 7 means that the agent will make trading decisions every 7 days.
        else:
            done = False

        return state, reward, SPX_reward, utility, done, self.worth

    def reset(self, worth):
        self.worth = worth
        self.SPX_worth = worth
        self.date = random.choice(self.env['^GSPC'].Date) #the agent has a random trading starting date
        self.initial_date = self.date
        initial_info,SPX_initial_info = get_info(self.env, self.initial_date)
        initial_state = np.array(initial_info.drop(['Date', 'stock'],axis=1))
        initial_SPX = np.array(SPX_initial_info.drop(['Date', 'stock'],axis=1))
        return initial_state, initial_SPX

# %% [markdown]
# # DDPG

# %%
#Set Hyperparameters
# Hyperparameters adapted for performance from
#https://ai.stackexchange.com/questions/22945/ddpg-doesnt-converge-for-mountaincarcontinuous-v0-gym-environment
capacity=1000000
batch_size=64
update_iteration=200
tau=0.01 # tau for soft updating
gamma=0.99 # discount factor
directory = './'
hidden1=64 # hidden layer for actor
hidden2=64 #hiiden laye for critic

class DDPG(object):
    def __init__(self, state_dim, action_dim):
        """
        Initializes the DDPG agent.
        Takes three arguments:
               state_dim which is the dimensionality of the state space,
               action_dim which is the dimensionality of the action space, and
               max_action which is the maximum value an action can take.

        Creates a replay buffer, an actor-critic  networks and their corresponding target networks.
        It also initializes the optimizer for both actor and critic networks alog with
        counters to track the number of training iterations.
        """
        self.replay_buffer = Replay_buffer()

        num_inputs = ((action_dim - 1) * state_dim) #  flatten info matrix; minus one since cash does not hold info


        self.actor = Actor(num_inputs, action_dim, hidden1).to(device)
        self.actor_target = Actor(num_inputs, action_dim,  hidden1).to(device)
        self.actor_target.load_state_dict(self.actor.state_dict())              #The state_dict method returns a dictionary containing the model's parameters and their corresponding values.
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=3e-3)     #By loading the initial weights, the target actor network starts with the same parameters as the main actor network.

        self.critic = Critic(num_inputs, action_dim,  hidden2).to(device)
        self.critic_target = Critic(num_inputs, action_dim,  hidden2).to(device)
        self.critic_target.load_state_dict(self.critic.state_dict())
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=2e-2)
        # learning rate



        self.num_critic_update_iteration = 0
        self.num_actor_update_iteration = 0
        self.num_training = 0




    def select_action(self, state):
        """
        takes the current state as input and returns an action to take in that state.
        It uses the actor network to map the state to an action.
        """
        #print(state)
        state = torch.FloatTensor(state.flatten()).to(device)
        return self.actor(state).cpu().detach().numpy().flatten() #.data is deprecated in newer versions of PyTorch, replaced by .detach()


    def update(self):
        """
        updates the actor and critic networks using a batch of samples from the replay buffer.
        For each sample in the batch, it computes the target Q value using the target critic network and the target actor network.
        It then computes the current Q value using the critic network and the action taken by the actor network.

        It computes the critic loss as the mean squared error between the target Q value and the current Q value, and
        updates the critic network using gradient descent.

        It then computes the actor loss as the negative mean Q value using the critic network and the actor network, and
        updates the actor network using gradient ascent.

        Finally, it updates the target networks using
        soft updates, where a small fraction of the actor and critic network weights are transferred to their target counterparts.
        This process is repeated for a fixed number of iterations.
        """
        #saving loss
        policy_loss = []
        value_loss = []

        for it in range(update_iteration):
            # For each Sample in replay buffer batch
             #print(f'siamo nel loop di update iteration numero {it}')
            state, next_state, action, reward, done = self.replay_buffer.sample(batch_size)
            #print(f'action dimension: {action.shape}, vales: {action}')#state is ok
            state = torch.FloatTensor(state.reshape(batch_size, -1))#.to(device)
            state = torch.FloatTensor(state).to(device)

            action = torch.FloatTensor(action).to(device)
            #print(f'action dimension: {action.shape}, values {action}')
            #print(f'1.....next_state type : {type(next_state)}, and shape: {next_state.shape}')
            next_state = torch.FloatTensor(next_state.reshape(batch_size, -1))#.to(device)
            #print(f'2.....next_state type : {type(next_state)}, and shape: {next_state.shape}')
            next_state = torch.FloatTensor(next_state).to(device)


            #print(f'next state dimension: {next_state.shape}, of type {next_state.type}')
            done = torch.FloatTensor(1-done).to(device) #create a tensor of 0(if done = true) and 1(if = false ), done = true means that the episode is done
            reward = torch.FloatTensor(reward).to(device)

            # Compute the target Q value
            target_Q = self.critic_target(next_state, self.actor_target(next_state))


            target_Q = reward + (done * gamma * target_Q).detach() #.detach() is used to detach the tensor from the computation graph, preventing gradients
                                                                # from flowing through target_Q during backpropagation. This is common in Q-learning to treat
            #print(f'target_Q: {target_Q.shape}') # --> [64,1]               # the target Q value as a constant during the optimization of the critic network.

            # Get current Q estimate
            current_Q = self.critic(state, action)


            # Compute critic loss
            critic_loss = F.mse_loss(current_Q, target_Q)
            value_loss.append(critic_loss.item())


            # Optimize the critic
            self.critic_optimizer.zero_grad()
            critic_loss.backward()
            self.critic_optimizer.step()

            # Compute actor loss as the negative mean Q value using the critic network and the actor network
            actor_loss = -self.critic(state, self.actor(state)).mean()
            policy_loss.append(actor_loss.item())


            # Optimize the actor
            self.actor_optimizer.zero_grad()
            actor_loss.backward()
            self.actor_optimizer.step()


            """
            Update the frozen target models using
            soft updates, where
            tau,a small fraction of the actor and critic network weights are transferred to their target counterparts.
            """
            for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
                target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)

            for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
                target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)


            self.num_actor_update_iteration += 1
            self.num_critic_update_iteration += 1
        value_loss = statistics.mean(value_loss)
        policy_loss = statistics.mean(policy_loss)
        return(value_loss, policy_loss)


    def save(self):
        """
        Saves the state dictionaries of the actor and critic networks to files
        """
        torch.save(self.actor.state_dict(), directory + 'actor.pth')
        torch.save(self.critic.state_dict(), directory + 'critic.pth')

    def load(self):
        """
        Loads the state dictionaries of the actor and critic networks to files
        """
        self.actor.load_state_dict(torch.load(directory + 'actor.pth'))
        self.critic.load_state_dict(torch.load(directory + 'critic.pth'))


    def save_model(self, path):
        if not os.path.exists(path):
            os.makedirs(path)

        ddpg_actor = os.path.join(path, 'ddpg_actor_weights')
        ddpg_crtic = os.path.join(path, 'ddpg_critic_weights')
        torch.save(self.actor.state_dict(), ddpg_actor)
        torch.save(self.critic.state_dict(), ddpg_crtic)

# %%
seed = 543
#memory = Replay_buffer()
noise_scale = 1.5
final_noise_scale = 0.5
worth = 20000
cycle = 7
rho = 3 # coefficient of risk aversion --> high = more risk adverse

# %%
import gym

# create the environment
env = trade_env(train, worth, cycle, rho)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Define different parameters for training the agent
max_episode=1800
max_time_steps= 500 #cycle = 7  maximum number of training days
ep_r = 0
total_step = 0
score_hist=[]
# for rensering the environmnet
render=True
render_interval=10
# for reproducibility
#env.seed(0)
torch.manual_seed(0)
np.random.seed(0)
#Environment action ans states
state_dim =  env.state_space #number of columns - 1 (to not consider column date) (if does not work try - 2, because maybe there is also the column date )
action_dim = env.action_space #is the number of stock + 1 (hold cash)
max_action = 1
min_Val = torch.tensor(1e-7).float().to(device)

# Exploration Noise#
exploration_noise=0.1
#exploration_noise=0.1 * max_action

# %%
# Create a DDPG instance
agent = DDPG(state_dim, action_dim)
print("action_dim: ", action_dim)
print("state_dim: ", state_dim)
num_inputs = ((action_dim - 1) * state_dim)
print("num_inputs: ", num_inputs)
Training_reward = []
Policy_loss = []
Value_loss = []
ep_reward = [] #each element is the total reward of the episode
ep_relative_training_reward = [] #each element is the total realativereward of the episode
updates = 0
total_reward = 0
PolicyLoss_csv_file_= f"/content/drive/MyDrive/TESI/02_parameters/Policy_losses/{cycle}_{max_episode}_{tau}_{gamma}.csv" # Critic_TrainingEpisode_NumEpisodes_Tau_Gamma
ValueLoss_csv_file = f"/content/drive/MyDrive/TESI/02_parameters/Value_losses/{cycle}_{max_episode}_{tau}_{gamma}.csv"
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# action_dim:  6
# state_dim:  16
# num_inputs:  80

# %%
# Train the agent for max_episodes
for i in range(max_episode):
    print("#========================================================================================#")
    print("episod number: ", i)
    episode_reward = 0
    abs_training_reward = 0
    relative_training_reward = 0
    step =0
    state, SPX_state = env.reset(worth)
    if env.date!=env.end_date: #train_env.date at the beginning is the starting training day
      print(env.date)
      for  t in range(max_time_steps):  #maximum lenght of each episode, for now is setted = 7 by the cycle variable

          #print("day since last decision (i.e. number of training days):", t)
          #print("state:", state)
          action = agent.select_action(state)
          #print("action: ", action, "action sum:", np.sum(action))
          # Add Gaussian noise to actions for exploration
          if i < 1000:
            action = (action + np.random.normal(0, 0.5, size=action_dim)).clip(-max_action, max_action)
          elif 1000 < i and i < 1500:
            action = (action + np.random.normal(0, 0.1, size=action_dim)).clip(-max_action, max_action)
          else:
            action = (action + np.random.normal(0, 0.01, size=action_dim)).clip(-max_action, max_action)

          #print("action: ", action, "action sum:", np.sum(action))
          next_state, reward, SPX_reward, utility, done, portfolio_worth = env.step(action) # env.step() takes numpy array as inputs
          #print(f'next state: {next_state}')
          relative_training_reward += (reward - SPX_reward)
          episode_reward += reward
          Training_reward += [reward]
          total_reward += reward

         #print(f'reward dimension before pushing: {reward.shape}, reward value:{reward}')
          #print(f'SPX_reward dimension before pushing: {relative_training_reward.shape}, value: {relative_training_reward}')
          #print(f'utility dimension before pushing: {utility.shape}, value {utility}')



          #if render and i >= render_interval : env.render()
          #print(f'next_state dimension before pushing: {next_state.shape}')
          agent.replay_buffer.push((state, next_state, action, relative_training_reward, float(done)))
          state = next_state
          if done: #True when 7 days of training are passed or we lose a certain amount
              break
          step += 1

      #score_hist.append(total_reward)
      ep_reward.append(episode_reward)
      ep_relative_training_reward.append(relative_training_reward)

      total_step += step+1
      print("Episode: \t{}, Episode Reward: \t{} Total Reward: \t{:0.2f}".format( i, episode_reward, total_reward))
      critic_loss, actor_loss = agent.update()
      #print(type(Value_loss))
      #print(type(critic_loss))
      Value_loss.append(critic_loss)
      print(f'Value_loss: {critic_loss}')
      Policy_loss.append(actor_loss)
      print(f'Policy_loss: {actor_loss}')
      #writer.add_scalar('loss/value', critic_loss, updates)
      #writer.add_scalar('loss/policy', actor_loss, updates)
      updates += 1
      #saving the losses
      with open(PolicyLoss_csv_file_, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(Policy_loss)

      with open(ValueLoss_csv_file, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(Value_loss)

      if i % 10 == 0:
          os.chdir("/content/drive/MyDrive/TESI/02_parameters") #saving the agent's parameter every 10 episodes
          agent.save()
#env.close()

agent.save_model('/content/drive/MyDrive/TESI/02_parameters')
# Out:
# #========================================================================================#
# episod number:  0
# 2021-06-17
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Streaming output truncated to the last 5000 lines.
# 2017-08-09
# Episode: 	965, Episode Reward: 	-650.1016455623212 Total Reward: 	62115.16
# Value_loss: 40608891161.6
# Policy_loss: -352515.52140625
# #========================================================================================#
# episod number:  966
# 2018-07-19
# Episode: 	966, Episode Reward: 	311.6972758908232 Total Reward: 	62426.86
# Value_loss: 40247849287.68
# Policy_loss: -349535.48609375
# #========================================================================================#
# episod number:  967
# 2018-12-13
# Episode: 	967, Episode Reward: 	-1463.4884412365755 Total Reward: 	60963.37
# Value_loss: 35726724904.96
# Policy_loss: -343083.6734375
# #========================================================================================#
# episod number:  968
# 2017-12-22
# Episode: 	968, Episode Reward: 	-10.781239322557667 Total Reward: 	60952.59
# Value_loss: 34554959421.44
# Policy_loss: -343057.0390625
# #========================================================================================#
# episod number:  969
# 2018-03-07
# Episode: 	969, Episode Reward: 	273.5798146910274 Total Reward: 	61226.17
# Value_loss: 37580766330.88
# Policy_loss: -348406.49984375
# #========================================================================================#
# episod number:  970
# 2015-11-23
# Episode: 	970, Episode Reward: 	289.2453328139636 Total Reward: 	61515.42
# Value_loss: 39145298549.76
# Policy_loss: -348074.91734375
# #========================================================================================#
# episod number:  971
# 2020-04-23
# Episode: 	971, Episode Reward: 	385.0779446742272 Total Reward: 	61900.49
# Value_loss: 36998586229.76
# Policy_loss: -346322.155
# #========================================================================================#
# episod number:  972
# 2015-09-10
# Episode: 	972, Episode Reward: 	40.071294328758086 Total Reward: 	61940.57
# Value_loss: 36203972940.8
# Policy_loss: -342644.99890625
# #========================================================================================#
# episod number:  973
# 2019-01-25
# Episode: 	973, Episode Reward: 	677.4431042976139 Total Reward: 	62618.01
# Value_loss: 36841713879.04
# Policy_loss: -342091.4540625
# #========================================================================================#
# episod number:  974
# 2018-08-31
# Episode: 	974, Episode Reward: 	-234.86707128999842 Total Reward: 	62383.14
# Value_loss: 38574601733.12
# Policy_loss: -343694.10765625
# #========================================================================================#
# episod number:  975
# 2018-11-28
# Episode: 	975, Episode Reward: 	-458.52673766057706 Total Reward: 	61924.61
# Value_loss: 38131538022.4
# Policy_loss: -346391.899375
# #========================================================================================#
# episod number:  976
# 2020-08-25
# Episode: 	976, Episode Reward: 	404.9154314662519 Total Reward: 	62329.53
# Value_loss: 38790755665.92
# Policy_loss: -342035.00203125
# #========================================================================================#
# episod number:  977
# 2018-04-12
# Episode: 	977, Episode Reward: 	368.1635644206435 Total Reward: 	62697.69
# Value_loss: 37109904245.76
# Policy_loss: -335237.840625
# #========================================================================================#
# episod number:  978
# 2017-11-07
# Episode: 	978, Episode Reward: 	-284.9359666173441 Total Reward: 	62412.76
# Value_loss: 37282182384.64
# Policy_loss: -339604.50203125
# #========================================================================================#
# episod number:  979
# 2021-02-17
# Episode: 	979, Episode Reward: 	-93.26265676404 Total Reward: 	62319.49
# Value_loss: 39169243888.64
# Policy_loss: -345261.0396875
# #========================================================================================#
# episod number:  980
# 2020-02-28
# Episode: 	980, Episode Reward: 	-4091.1117337371797 Total Reward: 	58228.38
# Value_loss: 42256999710.72
# Policy_loss: -342086.01890625
# #========================================================================================#
# episod number:  981
# 2017-02-03
# Episode: 	981, Episode Reward: 	119.55259712372572 Total Reward: 	58347.94
# Value_loss: 38970751293.44
# Policy_loss: -339290.59375
# #========================================================================================#
# episod number:  982
# 2018-06-22
# Episode: 	982, Episode Reward: 	11.59154729727743 Total Reward: 	58359.53
# Value_loss: 38893110958.08
# Policy_loss: -334158.49109375
# #========================================================================================#
# episod number:  983
# 2015-09-15
# Episode: 	983, Episode Reward: 	-373.71222882076836 Total Reward: 	57985.81
# Value_loss: 40550889927.68
# Policy_loss: -336827.64390625
# #========================================================================================#
# episod number:  984
# 2018-11-19
# Episode: 	984, Episode Reward: 	-285.7448707240983 Total Reward: 	57700.07
# Value_loss: 37794576348.16
# Policy_loss: -335939.42171875
# #========================================================================================#
# episod number:  985
# 2019-06-18
# Episode: 	985, Episode Reward: 	304.3801310501367 Total Reward: 	58004.45
# Value_loss: 35868911447.04
# Policy_loss: -326154.372734375
# #========================================================================================#
# episod number:  986
# 2018-05-03
# Episode: 	986, Episode Reward: 	837.5481366352542 Total Reward: 	58842.00
# Value_loss: 34019905525.76
# Policy_loss: -321636.8459375
# #========================================================================================#
# episod number:  987
# 2018-03-16
# Episode: 	987, Episode Reward: 	-911.8016593882712 Total Reward: 	57930.20
# Value_loss: 36750078289.92
# Policy_loss: -319898.086953125
# #========================================================================================#
# episod number:  988
# 2021-06-21
# Episode: 	988, Episode Reward: 	290.1129124829604 Total Reward: 	58220.31
# Value_loss: 37167599047.68
# Policy_loss: -313901.739765625
# #========================================================================================#
# episod number:  989
# 2020-04-15
# Episode: 	989, Episode Reward: 	440.2219512903612 Total Reward: 	58660.53
# Value_loss: 35845718220.8
# Policy_loss: -316530.678359375
# #========================================================================================#
# episod number:  990
# 2021-10-21
# Episode: 	990, Episode Reward: 	268.49236417481734 Total Reward: 	58929.02
# Value_loss: 38737705543.68
# Policy_loss: -332345.50140625
# #========================================================================================#
# episod number:  991
# 2017-08-04
# Episode: 	991, Episode Reward: 	-357.8762583348871 Total Reward: 	58571.15
# Value_loss: 37893491005.44
# Policy_loss: -327143.248125
# #========================================================================================#
# episod number:  992
# 2017-05-15
# Episode: 	992, Episode Reward: 	-466.19234584587684 Total Reward: 	58104.96
# Value_loss: 38613271797.76
# Policy_loss: -328487.19296875
# #========================================================================================#
# episod number:  993
# 2016-08-29
# Episode: 	993, Episode Reward: 	209.2035044683289 Total Reward: 	58314.16
# Value_loss: 37042704645.12
# Policy_loss: -325789.64984375
# #========================================================================================#
# episod number:  994
# 2020-07-01
# Episode: 	994, Episode Reward: 	-251.45145267215776 Total Reward: 	58062.71
# Value_loss: 36561031848.96
# Policy_loss: -329825.75640625
# #========================================================================================#
# episod number:  995
# 2016-08-24
# Episode: 	995, Episode Reward: 	-366.0933889092121 Total Reward: 	57696.61
# Value_loss: 37485027563.52
# Policy_loss: -326477.881328125
# #========================================================================================#
# episod number:  996
# 2019-07-19
# Episode: 	996, Episode Reward: 	151.78168732471022 Total Reward: 	57848.40
# Value_loss: 42221851827.2
# Policy_loss: -327484.145078125
# #========================================================================================#
# episod number:  997
# 2015-08-04
# Episode: 	997, Episode Reward: 	6.396113228642207 Total Reward: 	57854.79
# Value_loss: 36496625448.96
# Policy_loss: -327066.10109375
# #========================================================================================#
# episod number:  998
# 2016-09-14
# Episode: 	998, Episode Reward: 	629.379173899455 Total Reward: 	58484.17
# Value_loss: 40102219504.64
# Policy_loss: -325866.330703125
# #========================================================================================#
# episod number:  999
# 2017-10-18
# Episode: 	999, Episode Reward: 	-188.40504150070046 Total Reward: 	58295.77
# Value_loss: 37293653836.8
# Policy_loss: -316915.01828125
# #========================================================================================#
# episod number:  1000
# 2019-04-05
# Episode: 	1000, Episode Reward: 	-31.602852652489673 Total Reward: 	58264.16
# Value_loss: 39170480230.4
# Policy_loss: -321183.0528125
# #========================================================================================#
# episod number:  1001
# 2020-07-06
# Episode: 	1001, Episode Reward: 	874.2651393320702 Total Reward: 	59138.43
# Value_loss: 38587723914.24
# Policy_loss: -327911.562578125
# #========================================================================================#
# episod number:  1002
# 2016-11-14
# Episode: 	1002, Episode Reward: 	30.573612060507003 Total Reward: 	59169.00
# Value_loss: 43019393571.84
# Policy_loss: -329329.42546875
# #========================================================================================#
# episod number:  1003
# 2020-03-31
# Episode: 	1003, Episode Reward: 	1673.4473389694176 Total Reward: 	60842.45
# Value_loss: 41534697134.08
# Policy_loss: -322490.29703125
# #========================================================================================#
# episod number:  1004
# 2020-05-05
# Episode: 	1004, Episode Reward: 	-512.2718231947365 Total Reward: 	60330.18
# Value_loss: 39358729518.08
# Policy_loss: -324660.779921875
# #========================================================================================#
# episod number:  1005
# 2017-12-22
# Episode: 	1005, Episode Reward: 	172.04400440559039 Total Reward: 	60502.22
# Value_loss: 37627736499.2
# Policy_loss: -313622.0059375
# #========================================================================================#
# episod number:  1006
# 2018-04-06
# Episode: 	1006, Episode Reward: 	690.3465409410637 Total Reward: 	61192.57
# Value_loss: 39599070586.88
# Policy_loss: -309904.314375
# #========================================================================================#
# episod number:  1007
# 2019-11-19
# Episode: 	1007, Episode Reward: 	149.62268857722665 Total Reward: 	61342.19
# Value_loss: 35117147909.12
# Policy_loss: -308668.99375
# #========================================================================================#
# episod number:  1008
# 2020-07-08
# Episode: 	1008, Episode Reward: 	540.176892062751 Total Reward: 	61882.37
# Value_loss: 38041050675.2
# Policy_loss: -300808.3625
# #========================================================================================#
# episod number:  1009
# 2019-01-14
# Episode: 	1009, Episode Reward: 	349.21191162990726 Total Reward: 	62231.58
# Value_loss: 39532350858.24
# Policy_loss: -292425.735703125
# #========================================================================================#
# episod number:  1010
# 2016-01-28
# Episode: 	1010, Episode Reward: 	-266.25559687141504 Total Reward: 	61965.32
# Value_loss: 36473417543.68
# Policy_loss: -290272.57328125
# #========================================================================================#
# episod number:  1011
# 2015-08-06
# Episode: 	1011, Episode Reward: 	-58.90245641796355 Total Reward: 	61906.42
# Value_loss: 39979504322.56
# Policy_loss: -295483.723828125
# #========================================================================================#
# episod number:  1012
# 2021-04-19
# Episode: 	1012, Episode Reward: 	-200.44242064131322 Total Reward: 	61705.98
# Value_loss: 37182328504.32
# Policy_loss: -290300.07984375
# #========================================================================================#
# episod number:  1013
# 2019-12-19
# Episode: 	1013, Episode Reward: 	582.0366832492582 Total Reward: 	62288.02
# Value_loss: 36486537021.44
# Policy_loss: -287486.95640625
# #========================================================================================#
# episod number:  1014
# 2017-01-26
# Episode: 	1014, Episode Reward: 	-148.1283348158322 Total Reward: 	62139.89
# Value_loss: 38482810682.88
# Policy_loss: -292478.5028125
# #========================================================================================#
# episod number:  1015
# 2015-12-01
# Episode: 	1015, Episode Reward: 	-245.92170784157133 Total Reward: 	61893.97
# Value_loss: 39112300062.72
# Policy_loss: -284076.35609375
# #========================================================================================#
# episod number:  1016
# 2018-04-10
# Episode: 	1016, Episode Reward: 	605.4382439278888 Total Reward: 	62499.40
# Value_loss: 35710612510.72
# Policy_loss: -277025.82921875
# #========================================================================================#
# episod number:  1017
# 2020-05-08
# Episode: 	1017, Episode Reward: 	307.72121491824873 Total Reward: 	62807.13
# Value_loss: 37902672133.12
# Policy_loss: -279138.623515625
# #========================================================================================#
# episod number:  1018
# 2017-04-12
# Episode: 	1018, Episode Reward: 	-27.504179309660685 Total Reward: 	62779.62
# Value_loss: 39252859264.0
# Policy_loss: -279157.830625
# #========================================================================================#
# episod number:  1019
# 2016-02-19
# Episode: 	1019, Episode Reward: 	-148.96642668001732 Total Reward: 	62630.65
# Value_loss: 35251052395.52
# Policy_loss: -275624.95609375
# #========================================================================================#
# episod number:  1020
# 2016-01-28
# Episode: 	1020, Episode Reward: 	-366.53536235876163 Total Reward: 	62264.12
# Value_loss: 38861768473.6
# Policy_loss: -281548.891171875
# #========================================================================================#
# episod number:  1021
# 2019-08-26
# Episode: 	1021, Episode Reward: 	195.59955175184587 Total Reward: 	62459.72
# Value_loss: 34799780981.76
# Policy_loss: -284448.5446875
# #========================================================================================#
# episod number:  1022
# 2018-03-22
# Episode: 	1022, Episode Reward: 	219.65936449313813 Total Reward: 	62679.38
# Value_loss: 34577886924.8
# Policy_loss: -276147.671328125
# #========================================================================================#
# episod number:  1023
# 2021-10-22
# Episode: 	1023, Episode Reward: 	365.88846479777203 Total Reward: 	63045.27
# Value_loss: 42578300072.96
# Policy_loss: -283215.621328125
# #========================================================================================#
# episod number:  1024
# 2018-12-26
# Episode: 	1024, Episode Reward: 	-142.14814563672553 Total Reward: 	62903.12
# Value_loss: 40878025815.04
# Policy_loss: -284124.706484375
# #========================================================================================#
# episod number:  1025
# 2019-06-13
# Episode: 	1025, Episode Reward: 	553.3686797742193 Total Reward: 	63456.49
# Value_loss: 41289909524.48
# Policy_loss: -287234.663203125
# #========================================================================================#
# episod number:  1026
# 2020-05-26
# Episode: 	1026, Episode Reward: 	197.85862614024154 Total Reward: 	63654.35
# Value_loss: 40176955924.48
# Policy_loss: -294374.733671875
# #========================================================================================#
# episod number:  1027
# 2021-11-26
# Episode: 	1027, Episode Reward: 	769.1088022533004 Total Reward: 	64423.45
# Value_loss: 37879655393.28
# Policy_loss: -291646.544296875
# #========================================================================================#
# episod number:  1028
# 2018-04-17
# Episode: 	1028, Episode Reward: 	-579.9754988912391 Total Reward: 	63843.48
# Value_loss: 43599713433.6
# Policy_loss: -290728.468515625
# #========================================================================================#
# episod number:  1029
# 2018-07-30
# Episode: 	1029, Episode Reward: 	517.4443028817441 Total Reward: 	64360.92
# Value_loss: 40194874327.04
# Policy_loss: -279033.66640625
# #========================================================================================#
# episod number:  1030
# 2017-01-12
# Episode: 	1030, Episode Reward: 	-122.02943710178079 Total Reward: 	64238.89
# Value_loss: 34925339448.32
# Policy_loss: -270066.38125
# #========================================================================================#
# episod number:  1031
# 2019-05-08
# Episode: 	1031, Episode Reward: 	-13.477674995010602 Total Reward: 	64225.42
# Value_loss: 39908426741.76
# Policy_loss: -276779.386484375
# #========================================================================================#
# episod number:  1032
# 2019-08-23
# Episode: 	1032, Episode Reward: 	893.4600817084138 Total Reward: 	65118.88
# Value_loss: 38816469483.52
# Policy_loss: -270897.148515625
# #========================================================================================#
# episod number:  1033
# 2021-03-31
# Episode: 	1033, Episode Reward: 	300.8298418566774 Total Reward: 	65419.71
# Value_loss: 42348925916.16
# Policy_loss: -270722.782265625
# #========================================================================================#
# episod number:  1034
# 2019-07-01
# Episode: 	1034, Episode Reward: 	111.5768011726359 Total Reward: 	65531.28
# Value_loss: 39237882383.36
# Policy_loss: -264470.339140625
# #========================================================================================#
# episod number:  1035
# 2016-04-22
# Episode: 	1035, Episode Reward: 	-749.9480716929611 Total Reward: 	64781.33
# Value_loss: 36164346147.84
# Policy_loss: -265192.627109375
# #========================================================================================#
# episod number:  1036
# 2019-11-21
# Episode: 	1036, Episode Reward: 	291.4968380058708 Total Reward: 	65072.83
# Value_loss: 39555357629.44
# Policy_loss: -270806.6778125
# #========================================================================================#
# episod number:  1037
# 2018-11-29
# Episode: 	1037, Episode Reward: 	-984.9703551772909 Total Reward: 	64087.86
# Value_loss: 42441906997.76
# Policy_loss: -261057.08421875
# #========================================================================================#
# episod number:  1038
# 2016-02-26
# Episode: 	1038, Episode Reward: 	2573.595934453042 Total Reward: 	66661.46
# Value_loss: 39567133696.0
# Policy_loss: -260984.803125
# #========================================================================================#
# episod number:  1039
# 2018-02-05
# Episode: 	1039, Episode Reward: 	-743.3715119701592 Total Reward: 	65918.09
# Value_loss: 41217224913.92
# Policy_loss: -262977.162578125
# #========================================================================================#
# episod number:  1040
# 2018-02-27
# Episode: 	1040, Episode Reward: 	-346.61216711822635 Total Reward: 	65571.47
# Value_loss: 38674257459.2
# Policy_loss: -258725.4753125
# #========================================================================================#
# episod number:  1041
# 2021-06-17
# Episode: 	1041, Episode Reward: 	541.5377071670046 Total Reward: 	66113.01
# Value_loss: 46911811389.44
# Policy_loss: -265430.763125
# #========================================================================================#
# episod number:  1042
# 2015-07-23
# Episode: 	1042, Episode Reward: 	-312.2873008421411 Total Reward: 	65800.72
# Value_loss: 39040998709.76
# Policy_loss: -252509.3659375
# #========================================================================================#
# episod number:  1043
# 2017-07-11
# Episode: 	1043, Episode Reward: 	502.4278757165157 Total Reward: 	66303.15
# Value_loss: 39739529589.76
# Policy_loss: -252993.912421875
# #========================================================================================#
# episod number:  1044
# 2017-06-08
# Episode: 	1044, Episode Reward: 	575.825775496538 Total Reward: 	66878.98
# Value_loss: 43210415613.44
# Policy_loss: -254663.649375
# #========================================================================================#
# episod number:  1045
# 2016-08-22
# Episode: 	1045, Episode Reward: 	-255.6333080428667 Total Reward: 	66623.34
# Value_loss: 38553258741.76
# Policy_loss: -247490.55359375
# #========================================================================================#
# episod number:  1046
# 2019-07-15
# Episode: 	1046, Episode Reward: 	-77.79239488672829 Total Reward: 	66545.55
# Value_loss: 39223975009.28
# Policy_loss: -248579.76953125
# #========================================================================================#
# episod number:  1047
# 2019-12-09
# Episode: 	1047, Episode Reward: 	710.0279613793318 Total Reward: 	67255.58
# Value_loss: 38852424355.84
# Policy_loss: -252181.87140625
# #========================================================================================#
# episod number:  1048
# 2020-12-01
# Episode: 	1048, Episode Reward: 	125.15392701464953 Total Reward: 	67380.73
# Value_loss: 47493346411.52
# Policy_loss: -251293.698984375
# #========================================================================================#
# episod number:  1049
# 2020-04-17
# Episode: 	1049, Episode Reward: 	584.2870051960126 Total Reward: 	67965.02
# Value_loss: 38109478996.48
# Policy_loss: -243187.9328125
# #========================================================================================#
# episod number:  1050
# 2016-02-26
# Episode: 	1050, Episode Reward: 	2110.4532210839316 Total Reward: 	70075.47
# Value_loss: 41607191457.28
# Policy_loss: -248002.068203125
# #========================================================================================#
# episod number:  1051
# 2017-03-27
# Episode: 	1051, Episode Reward: 	62.009342124380055 Total Reward: 	70137.48
# Value_loss: 38330132633.6
# Policy_loss: -241623.88453125
# #========================================================================================#
# episod number:  1052
# 2021-06-30
# Episode: 	1052, Episode Reward: 	260.9837713855086 Total Reward: 	70398.47
# Value_loss: 38536805125.12
# Policy_loss: -237887.776953125
# #========================================================================================#
# episod number:  1053
# 2021-06-16
# Episode: 	1053, Episode Reward: 	-221.79949558605585 Total Reward: 	70176.67
# Value_loss: 37418165506.56
# Policy_loss: -231771.625703125
# #========================================================================================#
# episod number:  1054
# 2021-06-16
# Episode: 	1054, Episode Reward: 	-391.28250864536676 Total Reward: 	69785.39
# Value_loss: 41943786201.6
# Policy_loss: -239350.29828125
# #========================================================================================#
# episod number:  1055
# 2018-05-04
# Episode: 	1055, Episode Reward: 	1238.5422157509092 Total Reward: 	71023.93
# Value_loss: 35445117808.64
# Policy_loss: -235097.85859375
# #========================================================================================#
# episod number:  1056
# 2019-10-01
# Episode: 	1056, Episode Reward: 	-121.73486168909585 Total Reward: 	70902.19
# Value_loss: 36834603714.56
# Policy_loss: -233610.3215625
# #========================================================================================#
# episod number:  1057
# 2017-05-05
# Episode: 	1057, Episode Reward: 	28.366431010621454 Total Reward: 	70930.56
# Value_loss: 37397867824.64
# Policy_loss: -219203.06921875
# #========================================================================================#
# episod number:  1058
# 2020-02-21
# Episode: 	1058, Episode Reward: 	-2571.4244248000723 Total Reward: 	68359.13
# Value_loss: 39609946946.56
# Policy_loss: -223086.46609375
# #========================================================================================#
# episod number:  1059
# 2021-10-07
# Episode: 	1059, Episode Reward: 	1132.4806250850415 Total Reward: 	69491.62
# Value_loss: 37763610506.24
# Policy_loss: -221789.998828125
# #========================================================================================#
# episod number:  1060
# 2020-01-28
# Episode: 	1060, Episode Reward: 	407.0198685258001 Total Reward: 	69898.63
# Value_loss: 38184525086.72
# Policy_loss: -225632.89890625
# #========================================================================================#
# episod number:  1061
# 2020-07-10
# Episode: 	1061, Episode Reward: 	147.6145824813466 Total Reward: 	70046.25
# Value_loss: 37729057812.48
# Policy_loss: -228716.643828125
# #========================================================================================#
# episod number:  1062
# 2016-10-03
# Episode: 	1062, Episode Reward: 	73.86102806206327 Total Reward: 	70120.11
# Value_loss: 42826550906.88
# Policy_loss: -230037.3409375
# #========================================================================================#
# episod number:  1063
# 2020-09-17
# Episode: 	1063, Episode Reward: 	-517.7196968069256 Total Reward: 	69602.39
# Value_loss: 46429206420.48
# Policy_loss: -239430.596171875
# #========================================================================================#
# episod number:  1064
# 2017-05-17
# Episode: 	1064, Episode Reward: 	-183.29094937553964 Total Reward: 	69419.10
# Value_loss: 37948253890.56
# Policy_loss: -233615.521015625
# #========================================================================================#
# episod number:  1065
# 2021-02-26
# Episode: 	1065, Episode Reward: 	764.1955742427526 Total Reward: 	70183.30
# Value_loss: 43165907904.0
# Policy_loss: -248072.8534375
# #========================================================================================#
# episod number:  1066
# 2017-06-15
# Episode: 	1066, Episode Reward: 	71.78761937897798 Total Reward: 	70255.08
# Value_loss: 39383544294.4
# Policy_loss: -230231.625625
# #========================================================================================#
# episod number:  1067
# 2020-01-10
# Episode: 	1067, Episode Reward: 	-103.21299335729418 Total Reward: 	70151.87
# Value_loss: 39990721315.84
# Policy_loss: -236123.67453125
# #========================================================================================#
# episod number:  1068
# 2015-08-26
# Episode: 	1068, Episode Reward: 	496.3030813851001 Total Reward: 	70648.17
# Value_loss: 37086108495.36
# Policy_loss: -234408.25984375
# #========================================================================================#
# episod number:  1069
# 2017-04-12
# Episode: 	1069, Episode Reward: 	72.79731633357005 Total Reward: 	70720.97
# Value_loss: 38254891054.08
# Policy_loss: -240044.413671875
# #========================================================================================#
# episod number:  1070
# 2020-10-16
# Episode: 	1070, Episode Reward: 	-618.2755650606668 Total Reward: 	70102.69
# Value_loss: 35300391260.16
# Policy_loss: -233450.9903125
# #========================================================================================#
# episod number:  1071
# 2017-07-18
# Episode: 	1071, Episode Reward: 	400.2351610273836 Total Reward: 	70502.93
# Value_loss: 41290500646.4
# Policy_loss: -240298.199453125
# #========================================================================================#
# episod number:  1072
# 2021-08-18
# Episode: 	1072, Episode Reward: 	117.66082949789052 Total Reward: 	70620.59
# Value_loss: 39071236203.52
# Policy_loss: -244341.2215625
# #========================================================================================#
# episod number:  1073
# 2018-03-27
# Episode: 	1073, Episode Reward: 	1159.1570788516074 Total Reward: 	71779.75
# Value_loss: 36023447895.04
# Policy_loss: -242086.9309375
# #========================================================================================#
# episod number:  1074
# 2019-01-23
# Episode: 	1074, Episode Reward: 	469.87695355444885 Total Reward: 	72249.62
# Value_loss: 33793635258.88
# Policy_loss: -235536.0253125
# #========================================================================================#
# episod number:  1075
# 2019-08-12
# Episode: 	1075, Episode Reward: 	394.60516632960207 Total Reward: 	72644.23
# Value_loss: 36180960855.04
# Policy_loss: -239392.14421875
# #========================================================================================#
# episod number:  1076
# 2020-10-05
# Episode: 	1076, Episode Reward: 	390.27048678553183 Total Reward: 	73034.50
# Value_loss: 32366084582.4
# Policy_loss: -230772.635859375
# #========================================================================================#
# episod number:  1077
# 2019-09-16
# Episode: 	1077, Episode Reward: 	-193.0133575089385 Total Reward: 	72841.49
# Value_loss: 33298614159.36
# Policy_loss: -233836.289140625
# #========================================================================================#
# episod number:  1078
# 2016-11-03
# Episode: 	1078, Episode Reward: 	566.5010521442164 Total Reward: 	73407.99
# Value_loss: 35923269480.96
# Policy_loss: -221567.31234375
# #========================================================================================#
# episod number:  1079
# 2019-08-01
# Episode: 	1079, Episode Reward: 	-247.38462042577885 Total Reward: 	73160.60
# Value_loss: 31720234490.88
# Policy_loss: -213950.052109375
# #========================================================================================#
# episod number:  1080
# 2019-05-31
# Episode: 	1080, Episode Reward: 	779.3592857234835 Total Reward: 	73939.96
# Value_loss: 26294945881.6
# Policy_loss: -204143.611640625
# #========================================================================================#
# episod number:  1081
# 2016-04-14
# Episode: 	1081, Episode Reward: 	1105.2420121000978 Total Reward: 	75045.20
# Value_loss: 30283265886.72
# Policy_loss: -195925.481484375
# #========================================================================================#
# episod number:  1082
# 2020-02-24
# Episode: 	1082, Episode Reward: 	-1375.5196022354285 Total Reward: 	73669.69
# Value_loss: 27127621557.76
# Policy_loss: -201640.444609375
# #========================================================================================#
# episod number:  1083
# 2019-03-21
# Episode: 	1083, Episode Reward: 	-450.31006739151053 Total Reward: 	73219.38
# Value_loss: 26535027904.0
# Policy_loss: -194684.585625
# #========================================================================================#
# episod number:  1084
# 2018-06-18
# Episode: 	1084, Episode Reward: 	-252.1550291112144 Total Reward: 	72967.22
# Value_loss: 27954543841.28
# Policy_loss: -188046.940859375
# #========================================================================================#
# episod number:  1085
# 2018-03-28
# Episode: 	1085, Episode Reward: 	1278.7846570715737 Total Reward: 	74246.00
# Value_loss: 30930999390.72
# Policy_loss: -198549.123984375
# #========================================================================================#
# episod number:  1086
# 2017-03-23
# Episode: 	1086, Episode Reward: 	-4.441490128381702 Total Reward: 	74241.56
# Value_loss: 33728674708.48
# Policy_loss: -192005.5178125
# #========================================================================================#
# episod number:  1087
# 2020-07-20
# Episode: 	1087, Episode Reward: 	63.342713809997804 Total Reward: 	74304.91
# Value_loss: 30588992942.08
# Policy_loss: -192253.845625
# #========================================================================================#
# episod number:  1088
# 2017-07-06
# Episode: 	1088, Episode Reward: 	479.9803972314585 Total Reward: 	74784.89
# Value_loss: 23745086236.16
# Policy_loss: -190240.54421875
# #========================================================================================#
# episod number:  1089
# 2019-01-07
# Episode: 	1089, Episode Reward: 	907.3288240286201 Total Reward: 	75692.22
# Value_loss: 27984116805.12
# Policy_loss: -189395.77328125
# #========================================================================================#
# episod number:  1090
# 2017-03-10
# Episode: 	1090, Episode Reward: 	-107.25911129251472 Total Reward: 	75584.96
# Value_loss: 24859005954.56
# Policy_loss: -182967.540703125
# #========================================================================================#
# episod number:  1091
# 2020-06-08
# Episode: 	1091, Episode Reward: 	-3279.19935371638 Total Reward: 	72305.76
# Value_loss: 23828621731.84
# Policy_loss: -175841.9763671875
# #========================================================================================#
# episod number:  1092
# 2021-10-28
# Episode: 	1092, Episode Reward: 	-160.81576008768388 Total Reward: 	72144.94
# Value_loss: 25964360005.12
# Policy_loss: -174347.986171875
# #========================================================================================#
# episod number:  1093
# 2015-07-24
# Episode: 	1093, Episode Reward: 	374.00422461110793 Total Reward: 	72518.95
# Value_loss: 26203614639.36
# Policy_loss: -175432.2744921875
# #========================================================================================#
# episod number:  1094
# 2020-06-11
# Episode: 	1094, Episode Reward: 	819.166694607371 Total Reward: 	73338.11
# Value_loss: 26150783831.04
# Policy_loss: -177425.8015234375
# #========================================================================================#
# episod number:  1095
# 2016-11-09
# Episode: 	1095, Episode Reward: 	-468.78305592627294 Total Reward: 	72869.33
# Value_loss: 27029204584.96
# Policy_loss: -189117.2362890625
# #========================================================================================#
# episod number:  1096
# 2020-08-14
# Episode: 	1096, Episode Reward: 	-573.9748358269244 Total Reward: 	72295.35
# Value_loss: 28613819752.96
# Policy_loss: -189137.312734375
# #========================================================================================#
# episod number:  1097
# 2020-05-08
# Episode: 	1097, Episode Reward: 	-1247.5353137324346 Total Reward: 	71047.82
# Value_loss: 23009261358.08
# Policy_loss: -182803.994609375
# #========================================================================================#
# episod number:  1098
# 2020-11-13
# Episode: 	1098, Episode Reward: 	519.3462436793234 Total Reward: 	71567.17
# Value_loss: 23769872872.96
# Policy_loss: -179360.7190625
# #========================================================================================#
# episod number:  1099
# 2018-08-07
# Episode: 	1099, Episode Reward: 	79.29468093839023 Total Reward: 	71646.46
# Value_loss: 22831698641.92
# Policy_loss: -168376.596796875
# #========================================================================================#
# episod number:  1100
# 2020-02-13
# Episode: 	1100, Episode Reward: 	-190.46093342034874 Total Reward: 	71456.00
# Value_loss: 23387792028.16
# Policy_loss: -174672.754140625
# #========================================================================================#
# episod number:  1101
# 2021-10-08
# Episode: 	1101, Episode Reward: 	1042.7822747819882 Total Reward: 	72498.78
# Value_loss: 22658413186.56
# Policy_loss: -172148.3071484375
# #========================================================================================#
# episod number:  1102
# 2016-11-30
# Episode: 	1102, Episode Reward: 	716.7882563069033 Total Reward: 	73215.57
# Value_loss: 21333903406.08
# Policy_loss: -169571.436328125
# #========================================================================================#
# episod number:  1103
# 2021-02-03
# Episode: 	1103, Episode Reward: 	139.04934507934377 Total Reward: 	73354.62
# Value_loss: 21415453770.24
# Policy_loss: -174877.631328125
# #========================================================================================#
# episod number:  1104
# 2019-10-02
# Episode: 	1104, Episode Reward: 	319.98821283211146 Total Reward: 	73674.61
# Value_loss: 24139678133.76
# Policy_loss: -184667.16625
# #========================================================================================#
# episod number:  1105
# 2021-01-07
# Episode: 	1105, Episode Reward: 	23.734844085513032 Total Reward: 	73698.34
# Value_loss: 20897588876.8
# Policy_loss: -174600.6951953125
# #========================================================================================#
# episod number:  1106
# 2019-04-05
# Episode: 	1106, Episode Reward: 	-1144.6825071460953 Total Reward: 	72553.66
# Value_loss: 20760343842.56
# Policy_loss: -178023.7546875
# #========================================================================================#
# episod number:  1107
# 2017-08-25
# Episode: 	1107, Episode Reward: 	-315.95999701270193 Total Reward: 	72237.70
# Value_loss: 18448867943.68
# Policy_loss: -169997.317578125
# #========================================================================================#
# episod number:  1108
# 2018-01-25
# Episode: 	1108, Episode Reward: 	-1008.4182512689913 Total Reward: 	71229.28
# Value_loss: 15481769314.56
# Policy_loss: -164028.454921875
# #========================================================================================#
# episod number:  1109
# 2017-01-20
# Episode: 	1109, Episode Reward: 	302.2340027234495 Total Reward: 	71531.52
# Value_loss: 16010063255.04
# Policy_loss: -167896.666328125
# #========================================================================================#
# episod number:  1110
# 2020-06-01
# Episode: 	1110, Episode Reward: 	3796.752529683501 Total Reward: 	75328.27
# Value_loss: 13111562560.0
# Policy_loss: -157427.2924609375
# #========================================================================================#
# episod number:  1111
# 2017-03-30
# Episode: 	1111, Episode Reward: 	-282.7374147010487 Total Reward: 	75045.53
# Value_loss: 12963095948.8
# Policy_loss: -154179.20109375
# #========================================================================================#
# episod number:  1112
# 2019-04-25
# Episode: 	1112, Episode Reward: 	168.08794974744524 Total Reward: 	75213.62
# Value_loss: 13260795531.52
# Policy_loss: -151165.1204296875
# #========================================================================================#
# episod number:  1113
# 2015-08-11
# Episode: 	1113, Episode Reward: 	51.73527339814973 Total Reward: 	75265.35
# Value_loss: 18249692094.72
# Policy_loss: -165883.252265625
# #========================================================================================#
# episod number:  1114
# 2018-09-12
# Episode: 	1114, Episode Reward: 	172.1506706434957 Total Reward: 	75437.50
# Value_loss: 18627442516.48
# Policy_loss: -163259.17375
# #========================================================================================#
# episod number:  1115
# 2019-05-17
# Episode: 	1115, Episode Reward: 	-117.12451111902192 Total Reward: 	75320.38
# Value_loss: 16931634568.96
# Policy_loss: -153864.75734375
# #========================================================================================#
# episod number:  1116
# 2019-01-10
# Episode: 	1116, Episode Reward: 	1143.1342348137332 Total Reward: 	76463.51
# Value_loss: 19054804700.16
# Policy_loss: -153636.536875
# #========================================================================================#
# episod number:  1117
# 2019-11-27
# Episode: 	1117, Episode Reward: 	-675.0372085390118 Total Reward: 	75788.48
# Value_loss: 20285428067.84
# Policy_loss: -159084.523203125
# #========================================================================================#
# episod number:  1118
# 2020-10-02
# Episode: 	1118, Episode Reward: 	-135.10945275577978 Total Reward: 	75653.37
# Value_loss: 21556280921.6
# Policy_loss: -162219.249765625
# #========================================================================================#
# episod number:  1119
# 2020-02-12
# Episode: 	1119, Episode Reward: 	-205.7295474936691 Total Reward: 	75447.64
# Value_loss: 21378397583.36
# Policy_loss: -153963.861953125
# #========================================================================================#
# episod number:  1120
# 2019-12-05
# Episode: 	1120, Episode Reward: 	784.2810453886268 Total Reward: 	76231.92
# Value_loss: 18374036654.08
# Policy_loss: -157394.4934765625
# #========================================================================================#
# episod number:  1121
# 2017-06-08
# Episode: 	1121, Episode Reward: 	153.80976152592484 Total Reward: 	76385.73
# Value_loss: 20224854855.68
# Policy_loss: -157954.30125
# #========================================================================================#
# episod number:  1122
# 2018-08-21
# Episode: 	1122, Episode Reward: 	466.64040233864944 Total Reward: 	76852.37
# Value_loss: 19045860815.36
# Policy_loss: -160025.549140625
# #========================================================================================#
# episod number:  1123
# 2020-03-03
# Episode: 	1123, Episode Reward: 	-2488.8603018316935 Total Reward: 	74363.51
# Value_loss: 16076457817.6
# Policy_loss: -154605.037109375
# #========================================================================================#
# episod number:  1124
# 2016-08-25
# Episode: 	1124, Episode Reward: 	-269.99342194730707 Total Reward: 	74093.52
# Value_loss: 17287388285.44
# Policy_loss: -156022.229140625
# #========================================================================================#
# episod number:  1125
# 2021-09-01
# Episode: 	1125, Episode Reward: 	12.50220777298091 Total Reward: 	74106.02
# Value_loss: 14832325900.8
# Policy_loss: -147794.9966015625
# #========================================================================================#
# episod number:  1126
# 2015-12-29
# Episode: 	1126, Episode Reward: 	-805.2518526370623 Total Reward: 	73300.77
# Value_loss: 13748930161.92
# Policy_loss: -148161.5087890625
# #========================================================================================#
# episod number:  1127
# 2020-08-18
# Episode: 	1127, Episode Reward: 	-465.1716659038102 Total Reward: 	72835.59
# Value_loss: 14565545150.72
# Policy_loss: -144546.064609375
# #========================================================================================#
# episod number:  1128
# 2017-09-11
# Episode: 	1128, Episode Reward: 	526.0451915580343 Total Reward: 	73361.64
# Value_loss: 14064827128.32
# Policy_loss: -141788.4358203125
# #========================================================================================#
# episod number:  1129
# 2017-08-31
# Episode: 	1129, Episode Reward: 	-305.46651172627026 Total Reward: 	73056.17
# Value_loss: 14737574400.0
# Policy_loss: -137794.0586328125
# #========================================================================================#
# episod number:  1130
# 2019-03-01
# Episode: 	1130, Episode Reward: 	-281.8667082542088 Total Reward: 	72774.31
# Value_loss: 13606354935.04
# Policy_loss: -142702.363984375
# #========================================================================================#
# episod number:  1131
# 2018-09-28
# Episode: 	1131, Episode Reward: 	139.11388841773442 Total Reward: 	72913.42
# Value_loss: 14315201120.0
# Policy_loss: -139417.183828125
# #========================================================================================#
# episod number:  1132
# 2020-08-28
# Episode: 	1132, Episode Reward: 	-1221.7065455590237 Total Reward: 	71691.71
# Value_loss: 15199530735.36
# Policy_loss: -137270.4796875
# #========================================================================================#
# episod number:  1133
# 2018-01-24
# Episode: 	1133, Episode Reward: 	-899.4685977143927 Total Reward: 	70792.24
# Value_loss: 11143832195.84
# Policy_loss: -133679.3612109375
# #========================================================================================#
# episod number:  1134
# 2021-10-28
# Episode: 	1134, Episode Reward: 	330.441447276713 Total Reward: 	71122.69
# Value_loss: 11253976060.16
# Policy_loss: -132182.1751953125
# #========================================================================================#
# episod number:  1135
# 2019-04-03
# Episode: 	1135, Episode Reward: 	197.46574615233476 Total Reward: 	71320.15
# Value_loss: 14582014159.36
# Policy_loss: -134325.8958203125
# #========================================================================================#
# episod number:  1136
# 2019-10-04
# Episode: 	1136, Episode Reward: 	400.83587021542917 Total Reward: 	71720.99
# Value_loss: 9466701847.04
# Policy_loss: -126754.3913671875
# #========================================================================================#
# episod number:  1137
# 2018-03-19
# Episode: 	1137, Episode Reward: 	-441.7741138252459 Total Reward: 	71279.21
# Value_loss: 10538930235.52
# Policy_loss: -124869.1230859375
# #========================================================================================#
# episod number:  1138
# 2019-09-06
# Episode: 	1138, Episode Reward: 	2850.3377077328005 Total Reward: 	74129.55
# Value_loss: 9958090347.52
# Policy_loss: -129632.0412109375
# #========================================================================================#
# episod number:  1139
# 2015-10-01
# Episode: 	1139, Episode Reward: 	768.4370320364687 Total Reward: 	74897.99
# Value_loss: 10562146958.72
# Policy_loss: -132548.216640625
# #========================================================================================#
# episod number:  1140
# 2015-11-20
# Episode: 	1140, Episode Reward: 	-175.13992313056588 Total Reward: 	74722.85
# Value_loss: 13461167413.76
# Policy_loss: -130889.3563671875
# #========================================================================================#
# episod number:  1141
# 2020-11-25
# Episode: 	1141, Episode Reward: 	-96.37714143041376 Total Reward: 	74626.47
# Value_loss: 12937699484.16
# Policy_loss: -126906.6108984375
# #========================================================================================#
# episod number:  1142
# 2019-06-26
# Episode: 	1142, Episode Reward: 	770.430442173034 Total Reward: 	75396.90
# Value_loss: 11431077136.0
# Policy_loss: -121261.6241015625
# #========================================================================================#
# episod number:  1143
# 2017-11-29
# Episode: 	1143, Episode Reward: 	-78.96284561090215 Total Reward: 	75317.94
# Value_loss: 10152296011.52
# Policy_loss: -118920.983515625
# #========================================================================================#
# episod number:  1144
# 2016-01-25
# Episode: 	1144, Episode Reward: 	765.9855176636629 Total Reward: 	76083.92
# Value_loss: 9965260513.92
# Policy_loss: -116207.599140625
# #========================================================================================#
# episod number:  1145
# 2015-09-09
# Episode: 	1145, Episode Reward: 	149.5186657219674 Total Reward: 	76233.44
# Value_loss: 9177380969.6
# Policy_loss: -116620.0308984375
# #========================================================================================#
# episod number:  1146
# 2019-01-25
# Episode: 	1146, Episode Reward: 	179.40123254213177 Total Reward: 	76412.84
# Value_loss: 11273559819.52
# Policy_loss: -123373.32390625
# #========================================================================================#
# episod number:  1147
# 2021-11-17
# Episode: 	1147, Episode Reward: 	-631.4326001765439 Total Reward: 	75781.41
# Value_loss: 14209452227.84
# Policy_loss: -130999.3326171875
# #========================================================================================#
# episod number:  1148
# 2016-06-21
# Episode: 	1148, Episode Reward: 	-85.27321752206626 Total Reward: 	75696.14
# Value_loss: 11573470494.72
# Policy_loss: -129363.724296875
# #========================================================================================#
# episod number:  1149
# 2021-03-19
# Episode: 	1149, Episode Reward: 	409.39110306292787 Total Reward: 	76105.53
# Value_loss: 13803538725.12
# Policy_loss: -127505.954453125
# #========================================================================================#
# episod number:  1150
# 2019-09-26
# Episode: 	1150, Episode Reward: 	-125.60297646215986 Total Reward: 	75979.93
# Value_loss: 13699226695.68
# Policy_loss: -126171.9279296875
# ...
# Value_loss: 425660.26859375
# Policy_loss: -347.4228778171539
# #========================================================================================#
# episod number:  1739
# 2021-01-05
# Episode: 	1739, Episode Reward: 	1942.4941002656233 Total Reward: 	168101.82
# Value_loss: 451199.387109375
# Policy_loss: -381.2455639886856
# #========================================================================================#
# episod number:  1740
# 2020-01-06
# Episode: 	1740, Episode Reward: 	5910.872319806447 Total Reward: 	174012.69
# Value_loss: 455018.6680859375
# Policy_loss: -357.2586484622955
# #========================================================================================#
# episod number:  1741
# 2017-05-12
# Episode: 	1741, Episode Reward: 	-529.5525236704088 Total Reward: 	173483.14
# Value_loss: 455307.4565625
# Policy_loss: -361.6112684941292
# #========================================================================================#
# episod number:  1742
# 2021-12-09
# Episode: 	1742, Episode Reward: 	-1191.8730303625962 Total Reward: 	172291.27
# Value_loss: 441359.8523046875
# Policy_loss: -406.95847803115845
# #========================================================================================#
# episod number:  1743
# 2017-02-07
# Episode: 	1743, Episode Reward: 	-421.52032462140414 Total Reward: 	171869.75
# Value_loss: 481292.696953125
# Policy_loss: -390.2398179769516
# #========================================================================================#
# episod number:  1744
# 2019-12-09
# Episode: 	1744, Episode Reward: 	1683.0500640403916 Total Reward: 	173552.80
# Value_loss: 443623.9234375
# Policy_loss: -326.8332029116154
# #========================================================================================#
# episod number:  1745
# 2019-10-30
# Episode: 	1745, Episode Reward: 	2522.8209420984094 Total Reward: 	176075.62
# Value_loss: 462493.219453125
# Policy_loss: -350.08461171627044
# #========================================================================================#
# episod number:  1746
# 2016-08-10
# Episode: 	1746, Episode Reward: 	1881.9669078084225 Total Reward: 	177957.58
# Value_loss: 437622.0663671875
# Policy_loss: -369.326389169693
# #========================================================================================#
# episod number:  1747
# 2021-07-06
# Episode: 	1747, Episode Reward: 	-1392.2589046438225 Total Reward: 	176565.32
# Value_loss: 416793.865859375
# Policy_loss: -363.74072396993637
# #========================================================================================#
# episod number:  1748
# 2017-10-20
# Episode: 	1748, Episode Reward: 	-325.01401961527154 Total Reward: 	176240.31
# Value_loss: 398909.8164453125
# Policy_loss: -357.84010858535765
# #========================================================================================#
# episod number:  1749
# 2017-10-02
# Episode: 	1749, Episode Reward: 	-1343.947361525541 Total Reward: 	174896.36
# Value_loss: 411216.245
# Policy_loss: -369.5844871377945
# #========================================================================================#
# episod number:  1750
# 2016-07-19
# Episode: 	1750, Episode Reward: 	-1065.8707791648194 Total Reward: 	173830.49
# Value_loss: 459413.353984375
# Policy_loss: -383.4039529895783
# #========================================================================================#
# episod number:  1751
# 2019-02-12
# Episode: 	1751, Episode Reward: 	1621.2166726717733 Total Reward: 	175451.71
# Value_loss: 431311.2175
# Policy_loss: -397.9960877656937
# #========================================================================================#
# episod number:  1752
# 2021-12-15
# Episode: 	1752, Episode Reward: 	767.7356820301939 Total Reward: 	176219.44
# Value_loss: 454304.913359375
# Policy_loss: -439.13797448158266
# #========================================================================================#
# episod number:  1753
# 2017-09-27
# Episode: 	1753, Episode Reward: 	-164.288263117116 Total Reward: 	176055.16
# Value_loss: 417752.22640625
# Policy_loss: -407.79716314315795
# #========================================================================================#
# episod number:  1754
# 2018-01-23
# Episode: 	1754, Episode Reward: 	-1153.5741572405386 Total Reward: 	174901.58
# Value_loss: 422492.4875
# Policy_loss: -403.94240548729897
# #========================================================================================#
# episod number:  1755
# 2019-09-12
# Episode: 	1755, Episode Reward: 	1595.0542599527907 Total Reward: 	176496.64
# Value_loss: 452909.0351953125
# Policy_loss: -374.6975483512878
# #========================================================================================#
# episod number:  1756
# 2017-05-12
# Episode: 	1756, Episode Reward: 	-537.4480957926535 Total Reward: 	175959.19
# Value_loss: 410473.8616796875
# Policy_loss: -370.0705821466446
# #========================================================================================#
# episod number:  1757
# 2017-06-27
# Episode: 	1757, Episode Reward: 	579.7708038023775 Total Reward: 	176538.96
# Value_loss: 434521.7976953125
# Policy_loss: -380.16695728302
# #========================================================================================#
# episod number:  1758
# 2015-10-23
# Episode: 	1758, Episode Reward: 	667.0400877090833 Total Reward: 	177206.00
# Value_loss: 498849.10234375
# Policy_loss: -367.416122674942
# #========================================================================================#
# episod number:  1759
# 2017-03-24
# Episode: 	1759, Episode Reward: 	316.2718101011451 Total Reward: 	177522.27
# Value_loss: 445967.8151171875
# Policy_loss: -325.2709198975563
# #========================================================================================#
# episod number:  1760
# 2021-08-04
# Episode: 	1760, Episode Reward: 	1263.8321191832074 Total Reward: 	178786.10
# Value_loss: 415795.975
# Policy_loss: -335.4561628770828
# #========================================================================================#
# episod number:  1761
# 2018-03-26
# Episode: 	1761, Episode Reward: 	344.03629202405864 Total Reward: 	179130.14
# Value_loss: 447988.191875
# Policy_loss: -314.3695071220398
# #========================================================================================#
# episod number:  1762
# 2016-05-02
# Episode: 	1762, Episode Reward: 	-396.8099521117256 Total Reward: 	178733.33
# Value_loss: 447024.8334765625
# Policy_loss: -336.81379025936127
# #========================================================================================#
# episod number:  1763
# 2019-05-07
# Episode: 	1763, Episode Reward: 	376.14830086672737 Total Reward: 	179109.48
# Value_loss: 408992.40359375
# Policy_loss: -367.97221767902374
# #========================================================================================#
# episod number:  1764
# 2017-08-24
# Episode: 	1764, Episode Reward: 	-258.34152439622267 Total Reward: 	178851.14
# Value_loss: 442032.6257421875
# Policy_loss: -366.1275257778168
# #========================================================================================#
# episod number:  1765
# 2016-04-28
# Episode: 	1765, Episode Reward: 	-558.3098898510871 Total Reward: 	178292.83
# Value_loss: 413900.463359375
# Policy_loss: -357.122845082283
# #========================================================================================#
# episod number:  1766
# 2018-10-04
# Episode: 	1766, Episode Reward: 	-1329.1682015403203 Total Reward: 	176963.66
# Value_loss: 415163.4909375
# Policy_loss: -357.82451313972473
# #========================================================================================#
# episod number:  1767
# 2019-10-02
# Episode: 	1767, Episode Reward: 	-2459.7147368826663 Total Reward: 	174503.94
# Value_loss: 451094.225
# Policy_loss: -386.1204615592957
# #========================================================================================#
# episod number:  1768
# 2016-04-20
# Episode: 	1768, Episode Reward: 	120.18985495765446 Total Reward: 	174624.13
# Value_loss: 546031.262421875
# Policy_loss: -410.9830866718292
# #========================================================================================#
# episod number:  1769
# 2018-10-19
# Episode: 	1769, Episode Reward: 	-2130.7060779972308 Total Reward: 	172493.43
# Value_loss: 455185.5774609375
# Policy_loss: -397.15848952293396
# #========================================================================================#
# episod number:  1770
# 2017-06-16
# Episode: 	1770, Episode Reward: 	-1276.6708393968256 Total Reward: 	171216.76
# Value_loss: 434997.60203125
# Policy_loss: -382.0149015235901
# #========================================================================================#
# episod number:  1771
# 2017-06-07
# Episode: 	1771, Episode Reward: 	364.1482293140907 Total Reward: 	171580.90
# Value_loss: 451538.729609375
# Policy_loss: -343.2460073876381
# #========================================================================================#
# episod number:  1772
# 2017-10-26
# Episode: 	1772, Episode Reward: 	1549.902697509584 Total Reward: 	173130.81
# Value_loss: 441823.2290625
# Policy_loss: -382.95507898330686
# #========================================================================================#
# episod number:  1773
# 2020-10-23
# Episode: 	1773, Episode Reward: 	-3135.1630231977942 Total Reward: 	169995.64
# Value_loss: 500422.1530078125
# Policy_loss: -394.0262347507477
# #========================================================================================#
# episod number:  1774
# 2016-12-23
# Episode: 	1774, Episode Reward: 	-722.2269804572134 Total Reward: 	169273.42
# Value_loss: 439473.565
# Policy_loss: -368.690275888443
# #========================================================================================#
# episod number:  1775
# 2015-10-20
# Episode: 	1775, Episode Reward: 	89.91589247274896 Total Reward: 	169363.33
# Value_loss: 460606.400703125
# Policy_loss: -385.8134987163544
# #========================================================================================#
# episod number:  1776
# 2020-01-14
# Episode: 	1776, Episode Reward: 	-1366.227092858855 Total Reward: 	167997.11
# Value_loss: 468448.5759375
# Policy_loss: -458.6670241737366
# #========================================================================================#
# episod number:  1777
# 2021-06-25
# Episode: 	1777, Episode Reward: 	-1430.908039820024 Total Reward: 	166566.20
# Value_loss: 475811.5950390625
# Policy_loss: -428.2965969181061
# #========================================================================================#
# episod number:  1778
# 2018-03-15
# Episode: 	1778, Episode Reward: 	847.7990146876364 Total Reward: 	167414.00
# Value_loss: 489484.815390625
# Policy_loss: -395.2562902832031
# #========================================================================================#
# episod number:  1779
# 2016-07-14
# Episode: 	1779, Episode Reward: 	-985.3213356764572 Total Reward: 	166428.68
# Value_loss: 529428.805859375
# Policy_loss: -386.18923649787905
# #========================================================================================#
# episod number:  1780
# 2015-08-28
# Episode: 	1780, Episode Reward: 	-709.7902803619909 Total Reward: 	165718.89
# Value_loss: 454968.9806640625
# Policy_loss: -340.86381992340085
# #========================================================================================#
# episod number:  1781
# 2018-10-30
# Episode: 	1781, Episode Reward: 	141.33285282914585 Total Reward: 	165860.22
# Value_loss: 426998.8184375
# Policy_loss: -370.62154710292816
# #========================================================================================#
# episod number:  1782
# 2018-02-13
# Episode: 	1782, Episode Reward: 	-249.72862899765823 Total Reward: 	165610.49
# Value_loss: 506786.5791796875
# Policy_loss: -384.48918283462524
# #========================================================================================#
# episod number:  1783
# 2018-12-19
# Episode: 	1783, Episode Reward: 	-2256.9633493064393 Total Reward: 	163353.53
# Value_loss: 503974.1892578125
# Policy_loss: -381.7744770383835
# #========================================================================================#
# episod number:  1784
# 2017-06-23
# Episode: 	1784, Episode Reward: 	1329.4386822540182 Total Reward: 	164682.97
# Value_loss: 487724.491484375
# Policy_loss: -385.8468540120125
# #========================================================================================#
# episod number:  1785
# 2019-02-21
# Episode: 	1785, Episode Reward: 	317.11597232811255 Total Reward: 	165000.08
# Value_loss: 513436.0212109375
# Policy_loss: -367.5515493011475
# #========================================================================================#
# episod number:  1786
# 2016-10-04
# Episode: 	1786, Episode Reward: 	-319.87725478335415 Total Reward: 	164680.20
# Value_loss: 467229.918828125
# Policy_loss: -355.1579149889946
# #========================================================================================#
# episod number:  1787
# 2016-08-24
# Episode: 	1787, Episode Reward: 	-1069.1817051225298 Total Reward: 	163611.02
# Value_loss: 428613.840859375
# Policy_loss: -363.58223057746886
# #========================================================================================#
# episod number:  1788
# 2015-10-16
# Episode: 	1788, Episode Reward: 	-356.52980108320116 Total Reward: 	163254.49
# Value_loss: 391058.321953125
# Policy_loss: -341.9758475589752
# #========================================================================================#
# episod number:  1789
# 2019-06-04
# Episode: 	1789, Episode Reward: 	-188.8482591091888 Total Reward: 	163065.64
# Value_loss: 491020.589296875
# Policy_loss: -380.93973069667817
# #========================================================================================#
# episod number:  1790
# 2021-08-19
# Episode: 	1790, Episode Reward: 	3255.9842787087 Total Reward: 	166321.63
# Value_loss: 458820.694453125
# Policy_loss: -368.2127300786972
# #========================================================================================#
# episod number:  1791
# 2021-12-28
# Episode: 	1791, Episode Reward: 	978.9234926793724 Total Reward: 	167300.55
# Value_loss: 509517.312109375
# Policy_loss: -396.09255438804627
# #========================================================================================#
# episod number:  1792
# 2018-06-08
# Episode: 	1792, Episode Reward: 	304.7136319639976 Total Reward: 	167605.27
# Value_loss: 411818.14359375
# Policy_loss: -373.32423727035524
# #========================================================================================#
# episod number:  1793
# 2021-04-01
# Episode: 	1793, Episode Reward: 	-1566.551096286741 Total Reward: 	166038.71
# Value_loss: 474482.22875
# Policy_loss: -381.7962111401558
# #========================================================================================#
# episod number:  1794
# 2018-03-02
# Episode: 	1794, Episode Reward: 	353.15525210466876 Total Reward: 	166391.87
# Value_loss: 466427.05234375
# Policy_loss: -378.326355509758
# #========================================================================================#
# episod number:  1795
# 2021-05-20
# Episode: 	1795, Episode Reward: 	148.95790468231644 Total Reward: 	166540.83
# Value_loss: 439087.9878125
# Policy_loss: -350.0820982825756
# #========================================================================================#
# episod number:  1796
# 2015-08-06
# Episode: 	1796, Episode Reward: 	156.53225450304308 Total Reward: 	166697.36
# Value_loss: 459507.81234375
# Policy_loss: -348.8351077747345
# #========================================================================================#
# episod number:  1797
# 2016-10-10
# Episode: 	1797, Episode Reward: 	-407.0662364850614 Total Reward: 	166290.29
# Value_loss: 415985.104609375
# Policy_loss: -321.8596889019012
# #========================================================================================#
# episod number:  1798
# 2019-07-03
# Episode: 	1798, Episode Reward: 	-355.60088501478094 Total Reward: 	165934.69
# Value_loss: 437748.7083984375
# Policy_loss: -337.34699536323546
# #========================================================================================#
# episod number:  1799
# 2019-09-10
# Episode: 	1799, Episode Reward: 	1348.265843860845 Total Reward: 	167282.96
# Value_loss: 435739.025546875
# Policy_loss: -310.13891099452974

# %% [markdown]
# #Training evaluation

# %%
def moving_average(data, window_size):
    cumsum = np.cumsum(data, dtype=float)
    cumsum[window_size:] = cumsum[window_size:] - cumsum[:-window_size]
    return cumsum[window_size - 1:] / window_size
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Value_loss = [int(tensor.item()) for tensor in Value_loss]

window_size = 500

moving_avg = moving_average(Value_loss, window_size)

plt.figure(figsize=(8, 5))
plt.plot(np.arange(window_size - 1, len(Value_loss)), moving_avg, label='Value Loss')
plt.xlabel('Episode')
plt.ylabel('Value')
plt.title('Value Loss')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
#FOCUS ON THE LAST VALUES
window_size = 500
moving_avg = moving_average(Value_loss, window_size)
num_values = 770  # Number of values to plot

plt.figure(figsize=(8, 5))
plt.plot(np.arange(len(Value_loss) - num_values, len(Value_loss)), moving_avg[-num_values:], label='Value Loss')
plt.xlabel('Episode')
plt.ylabel('Value')
plt.title('Value Loss')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
#Policy_loss = [int(tensor.item()) for tensor in Policy_loss]

window_size = 100
data = Policy_loss
moving_avg = moving_average(data, window_size)



plt.figure(figsize=(8, 5))  # Adjust figure size as needed
#plt.plot(data, marker='o', linestyle='-', color='b', label='Original Data')
plt.plot(np.arange(window_size - 1, len(data)), moving_avg, linestyle='-', color='tab:blue', label='Moving Average')
plt.xlabel('Episode')
plt.ylabel('Loss')
plt.title('Policy Loss')
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
#FOCUS ON THE LAST VALUES
window_size = 500
moving_avg = moving_average(Policy_loss, window_size)
num_values = 900  # Number of values to plot

plt.figure(figsize=(8, 5))
plt.plot(np.arange(len(Policy_loss) - num_values, len(Policy_loss)), moving_avg[-num_values:], label='Value Loss')
plt.xlabel('Episode')
plt.ylabel('Value')
plt.title('Value Loss')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
#Episode rewards


window_size = 1000
data = ep_relative_training_reward
moving_avg = moving_average(data, window_size)

plt.figure(figsize=(8, 5))  # Adjust figure size as needed
plt.plot(np.arange(window_size - 1, len(data)), moving_avg, label='Moving Average')
plt.xlabel('Episode')
plt.ylabel('Episode return')
plt.title('Episode return')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
#Plotting each single reward
window_size  = 200
moving_avg = np.convolve(Training_reward, np.ones(window_size)/window_size, mode='valid')

# Plot the moving average
plt.plot(np.arange(window_size-1, len(Training_reward)), moving_avg, label='Moving Average')
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Plotting each single reward')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
plt.plot(ep_reward, label='Reward')

# %%
np.median(Training_reward)
# Out:
# 14.1899835883778

# %%
np.std(Training_reward)
# Out:
# 406.42500751447557

# %%
sns.distplot(Training_reward)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # Testing the DDPG Agent

# %%
import warnings
warnings.filterwarnings("ignore", message="np.find_common_type is deprecated", category=DeprecationWarning)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def baseline_plot(baseline_df, portfolio_return ):

  fig, axs = plt.subplots(1, 2, figsize=(12, 6))  # 1 row, 2 columns

  baseline_df['Value'][0]
  percentage_return_portfolio = (portfolio_return - portfolio_return[0]) / portfolio_return[0] * 100
  percentage_return_baseline = (baseline_df['Value'] - baseline_df['Value'][0]) / baseline_df['Value'][0] * 100

  plt.plot(percentage_return_portfolio, label='Portfolio')
  plt.plot(percentage_return_baseline, label='Baseline')

  # Add title and labels
  plt.title('Percentage Return of Portfolio')
  plt.xlabel('Date')
  plt.ylabel('Percentage Return')

  # Show legend
  plt.legend()

  # Show grid
  plt.grid(True)

  # Show plot
  plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def test_plots(baseline_df, portfolio_return, SP_return ):

  fig, axs = plt.subplots(1, 2, figsize=(12, 6))  # 1 row, 2 columns
  #first plot
  baseline_df['Value'][0]
  percentage_return_portfolio = (portfolio_return - portfolio_return[0]) / portfolio_return[0] * 100
  percentage_return_baseline = (baseline_df['Value'] - baseline_df['Value'][0]) / baseline_df['Value'][0] * 100

  axs[0].plot(percentage_return_portfolio, label='Portfolio')
  axs[0].plot(percentage_return_baseline, label='Baseline')

  # Add title and labels
  axs[0].set_title('Percentage Return of Portfolio vs Baseline')
  axs[0].set_xlabel('Date')
  axs[0].set_ylabel('Percentage Return')
  axs[0].legend()
  axs[0].grid(True)

  #second plot
  percentage_return_portfolio = (portfolio_return - portfolio_return[0]) / portfolio_return[0] * 100
  SP_return = np.array(SP_return, dtype=np.float64)
  percentage_return_SP500 = (SP_return - SP_return[0]) / SP_return[0] * 100

  axs[1].plot(percentage_return_portfolio, label='Portfolio')
  axs[1].plot(percentage_return_SP500, label='SP500')
  axs[1].set_title('Percentage Return of Portfolio vs. SP500')
  axs[1].set_xlabel('Date')
  axs[1].set_ylabel('Percentage Return')
  axs[1].legend()
  axs[1].grid(True)

  # Adjust layout to prevent overlap
  plt.tight_layout()


  # Show plot
  plt.show()

def net_return_calculator(portfolio_return, SP_return): #calculate the difference between the portfolio return and the SP500 retun
    percentage_return_portfolio = (portfolio_return[-1] - portfolio_return[0]) / portfolio_return[0] * 100
    SP_return = np.array(SP_return, dtype=np.float64)
    percentage_return_SP500 = (SP_return[-1] - SP_return[0]) / SP_return[0] * 100

    net_return = percentage_return_portfolio - percentage_return_SP500

    return net_return

def return_histo(data):

  sns.set(style="whitegrid")

  # Create histogram
  sns.histplot(data, bins = 30 , kde=False, color='skyblue', edgecolor='black')
  mu, std = norm.fit(data)

# Plot fitted normal distribution
  plt.text(0.75, 0.95, f'Mean: {mu:.2f}\nStd: {std:.2f}', transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.5))


  # Customize labels and title
  plt.xlabel('Perid Percentage Return', fontsize=14)
  plt.ylabel('Frequency', fontsize=14)
  #plt.title('Return Distribution', fontsize=16)
  plt.legend()



  # Show plot
  plt.show()

# %%
env.env["AAPL"]
# Out:
#             Date       close     volume      macd     boll_ub     boll_lb  \
# 0     2015-07-20   29.757948  235600800  0.071435   32.850209   30.297291
# 1     2015-07-21   29.460520  307025600  0.136149   32.977277   30.248723
# 2     2015-07-22   28.214500  461802400  0.075014   32.959562   30.221188
# 3     2015-07-23   28.200985  203998000  0.025065   32.912807   30.194193
# 4     2015-07-24   28.052271  168649200 -0.027517   32.879337   30.152663
# ...          ...         ...        ...       ...         ...         ...
# 1624  2021-12-29  177.127609   62348900  5.092459  184.389297  161.849703
# 1625  2021-12-30  175.962387   59773000  4.932099  184.555157  163.026842
# 1626  2021-12-31  175.340332   64062300  4.699999  184.263252  164.699748
# 1627  2022-01-03  179.724579  104487900  4.818780  183.837983  167.142017
# 1628  2022-01-04  177.443573   99310400  4.672654  183.242423  169.175576
#
#          rsi_30      dx_30  close_30_sma  close_60_sma        N1        N5  \
# 0     57.082043   3.353520     31.683833     31.971667  0.018725  0.049753
# 1     55.083267   2.102349     31.708417     31.973625 -0.010045  0.040105
# 2     47.825601  19.890138     31.690083     31.942667 -0.043215 -0.012696
# 3     47.754981  14.999036     31.659083     31.920167 -0.000479 -0.026414
# 4     46.965784  17.538024     31.625000     31.902917 -0.005287 -0.040301
# ...         ...        ...           ...           ...       ...       ...
# 1624  64.017157  40.369287    168.400667    157.946834  0.000502  0.036273
# 1625  62.817265  40.245186    169.307334    158.565000 -0.006600  0.014470
# 1626  62.173653  38.147916    170.110001    159.157834 -0.003541  0.007291
# 1627  64.802855  42.087725    170.914667    159.803167  0.024697  0.009273
# 1628  62.466028  42.150384    171.553000    160.416501 -0.012773  0.002284
#
#         N1_mon    N6_mon    R1_std    R2_std  weekday stock
# 0     0.037808  0.202663  0.013984  0.013926        0  AAPL
# 1     0.029730  0.185013  0.014012  0.013859        1  AAPL
# 2    -0.018828  0.116115  0.014402  0.014140        2  AAPL
# 3    -0.016954  0.110489  0.014398  0.014136        3  AAPL
# 4    -0.026787  0.104141  0.014408  0.014119        4  AAPL
# ...        ...       ...       ...       ...      ...   ...
# 1624  0.107978  0.270512  0.014208  0.015859        2  AAPL
# 1625  0.098959  0.244505  0.014144  0.015779        3  AAPL
# 1626  0.092139  0.226353  0.014106  0.015767        4  AAPL
# 1627  0.149027  0.233253  0.014183  0.015675        0  AAPL
# 1628  0.114616  0.229723  0.014208  0.015567        1  AAPL
#
# [1629 rows x 18 columns]

# %%
test_env = trade_env(test, worth, 7, rho)
test_env.env["AAPL"]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#            Date       close     volume      macd     boll_ub     boll_lb  \
# 0    2022-01-05  172.723572   94537600  4.123607  183.055370  169.736630
# 1    2022-01-06  169.840271   96904000  3.413516  183.166675  169.317324
# 2    2022-01-07  170.008118   86709100  2.831837  183.248942  168.996058
# 3    2022-01-10  170.027847  106765600  2.345430  182.911846  168.607154
# 4    2022-01-11  172.881577   76138300  2.168154  182.885312  168.567688
# ..          ...         ...        ...       ...         ...         ...
# 503  2024-01-08  185.323517   59144500 -1.485219  202.951512  181.451490
# 504  2024-01-09  184.904053   42841800 -1.611037  202.731619  180.614382
# 505  2024-01-10  185.952713   46792900 -1.607493  202.620833  180.026168
# 506  2024-01-11  185.353485   49128400 -1.634261  202.324395  179.410605
# 507  2024-01-12  185.683060   40444700 -1.610284  201.414379  179.116621
#
#         rsi_30      dx_30  close_30_sma  close_60_sma        N1        N5  \
# 0    57.989692  31.186369    172.016334    160.951667 -0.026960 -0.025178
# 1    55.477384  24.532545    172.369333    161.459834 -0.016834 -0.035412
# 2    55.593250  23.217959    172.710333    161.980834  0.000988 -0.030883
# 3    55.607313  17.216539    173.223000    162.454667  0.000116 -0.055463
# 4    57.613473  20.948859    173.717667    162.958668  0.016645 -0.026046
# ..         ...        ...           ...           ...       ...       ...
# 503  48.190931   9.436528    191.806333    185.691667  0.023887 -0.036874
# 504  47.776921   9.436528    191.645333    185.765500 -0.002266 -0.002697
# 505  48.912011   6.474435    191.525334    185.887834  0.005655  0.010474
# 506  48.291532   4.946388    191.365000    186.002334 -0.003228  0.020028
# 507  48.662071   4.946388    191.250001    186.148500  0.001777  0.025825
#
#        N1_mon    N6_mon    R1_std    R2_std  weekday stock
# 0    0.056567  0.189792  0.014404  0.015662        2  AAPL
# 1    0.042944  0.177171  0.014488  0.015626        3  AAPL
# 2    0.050081  0.170300  0.014477  0.015625        4  AAPL
# 3    0.061990  0.146601  0.014335  0.015596        0  AAPL
# 4    0.057360  0.167748  0.014392  0.015592        1  AAPL
# ..        ...       ...       ...       ...      ...   ...
# 503 -0.023383 -0.010823  0.012564  0.012659        0  AAPL
# 504 -0.032417 -0.022035  0.012539  0.012659        1  AAPL
# 505 -0.017252 -0.020428  0.012544  0.012602        2  AAPL
# 506 -0.041324 -0.024443  0.012547  0.012605        3  AAPL
# 507 -0.033844 -0.039824  0.012451  0.012592        4  AAPL
#
# [508 rows x 18 columns]

# %%
import os
actor_weights = os.path.join('/content/drive/MyDrive/TESI/02_parameters', 'Critic_7_2000_0001_0999') #Critic_TrainingEpisode_NumEpisodes_Tau_Gamma
critic_weights =os.path.join('/content/drive/MyDrive/TESI/02_parameters', 'Actor_7_2000_0001_0999')

test_cycle = 180

test_env = trade_env(test, worth, test_cycle, rho)

test_iteration=100
reward_list = []
net_return_list = [] #lista con differenza tra ritorni portfolio e ritoni SP
net_return_portfolio_list = [] #lista con ritorni del portfolio
net_return_SP_list = []
for i in range(test_iteration):
    state, SPX_state = test_env.reset(worth)
    start_date = test_env.date
    portfolio_return = []
    SP_return = []
    Date = []
    for t in count():
        action = agent.select_action(state)
        next_state, reward, SPX_reward, utility, done, portfolio_worth = test_env.step(action)
        portfolio_return.append(portfolio_worth)
        ep_r += reward
        #print(f"PORTFOLIO VALUE: {portfolio_worth} at iteration {t}")
        reward_list += [reward]
        #print(test_env.date)
        SP_return.append(test_env.env['^GSPC'][test_env.env['^GSPC']['Date'] == test_env.date ]['close'].item())
        Date.append(test_env.date)
        #env.render()
        if done:
            net_return = net_return_calculator(portfolio_return, SP_return)#differenza tra ritorno finale del portfolio e ritorno finale SP500
            net_return_list.append(net_return)
            net_return_portfolio = (portfolio_return[-1] - portfolio_return[0])/portfolio_return[0] * 100
            net_return_portfolio_list.append(net_return_portfolio)
            net_return_SP = (SP_return[-1] - SP_return[0])/SP_return[0] * 100
            net_return_SP_list.append(net_return_SP)
            print(f"reward:{reward}, net return: {net_return}")
            print("Episode \t{}, the episode reward is \t{:0.2f}".format(i, ep_r))
            end_date = test_env.date
            ep_r = 0
            baseline_df =  baseline_portfolio(test_env.env, start_date, 20000, end_date)
            #if t%10 == 0:
              #test_plots(baseline_df, portfolio_return, SP_return)

            #env.render()

            break
        state = next_state
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# reward:45.86372375488281, net return: -10.306455383211416
# Episode 	0, the episode reward is 	-1324.30
# reward:-403.90102767944336, net return: 13.996484821001687
# Episode 	1, the episode reward is 	4055.67
# reward:-390.2049407958948, net return: -7.067459297910151
# Episode 	2, the episode reward is 	-2028.21
# reward:-71.53147506713867, net return: 2.6786480731859745
# Episode 	3, the episode reward is 	2186.23
# reward:-520.4311561584473, net return: -18.336921579655407
# Episode 	4, the episode reward is 	-2130.60
# reward:-609.7470474243164, net return: 4.68434179359655
# Episode 	5, the episode reward is 	-2245.32
# reward:44.59455871582031, net return: -18.036700811550762
# Episode 	6, the episode reward is 	-1861.51
# reward:-12.380386352535425, net return: 30.310166391365087
# Episode 	7, the episode reward is 	6013.81
# reward:823.515754699707, net return: 15.973075912886422
# Episode 	8, the episode reward is 	1494.67
# reward:281.48955535889763, net return: 6.718606086133196
# Episode 	9, the episode reward is 	-275.53
# reward:-773.6326942443811, net return: -5.599545944072947
# Episode 	10, the episode reward is 	-2087.91
# reward:48.71797943115598, net return: 17.11604833933352
# Episode 	11, the episode reward is 	4189.25
# reward:-403.90102767944336, net return: 13.996484821001687
# Episode 	12, the episode reward is 	4055.67
# reward:-644.5918121337854, net return: -4.5133661312180395
# Episode 	13, the episode reward is 	-2112.18
# reward:-1356.4101867675818, net return: -9.681748720764519
# Episode 	14, the episode reward is 	-3049.34
# reward:-520.4311561584473, net return: -13.930482354013137
# Episode 	15, the episode reward is 	-2121.75
# reward:-528.1707801818848, net return: -20.69919081160436
# Episode 	16, the episode reward is 	-2155.52
# reward:-741.861644744873, net return: -5.12011619393006
# Episode 	17, the episode reward is 	-2059.58
# reward:-709.0813827514612, net return: -2.0846764632944277
# Episode 	18, the episode reward is 	-2109.18
# reward:-1097.3025341033936, net return: 19.771946129116078
# Episode 	19, the episode reward is 	-1.38
# reward:282.94749450682866, net return: 33.05190124842399
# Episode 	20, the episode reward is 	5591.49
# reward:-1625.104835510254, net return: 0.09641942042814833
# Episode 	21, the episode reward is 	-2460.75
# reward:-751.7251129150391, net return: -10.081815576756828
# Episode 	22, the episode reward is 	-2656.09
# reward:1015.9139709472656, net return: 27.85570367178703
# Episode 	23, the episode reward is 	6600.99
# reward:282.94749450682866, net return: 33.05190124842399
# Episode 	24, the episode reward is 	5591.49
# reward:-524.084156036377, net return: -12.50076819099197
# Episode 	25, the episode reward is 	-2270.38
# reward:-24.060569763183594, net return: 21.14945907811136
# Episode 	26, the episode reward is 	5549.40
# reward:-94.80260467529297, net return: -5.541072929996291
# Episode 	27, the episode reward is 	-2019.28
# reward:-1625.104835510254, net return: 0.09641942042814833
# Episode 	28, the episode reward is 	-2460.75
# reward:-710.1823196411133, net return: -13.416590788752249
# Episode 	29, the episode reward is 	-2216.08
# reward:-524.084156036377, net return: -12.950298929530854
# Episode 	30, the episode reward is 	-2294.78
# reward:-1599.1335182189941, net return: -2.9248731007883695
# Episode 	31, the episode reward is 	-2702.41
# reward:193.92635345459348, net return: 7.4028415878148
# Episode 	32, the episode reward is 	2352.13
# reward:-1036.6002311706543, net return: -10.01524062154822
# Episode 	33, the episode reward is 	-2491.10
# reward:-1356.4101867675818, net return: -9.681748720764519
# Episode 	34, the episode reward is 	-3049.34
# reward:-967.7312355041504, net return: -8.006819834072196
# Episode 	35, the episode reward is 	-2015.71
# reward:-702.9790649414062, net return: -7.215210776444351
# Episode 	36, the episode reward is 	-2389.17
# reward:135.5073471069336, net return: 1.1344150054386546
# Episode 	37, the episode reward is 	1286.02
# reward:-662.0188522338831, net return: 32.044356247083684
# Episode 	38, the episode reward is 	6985.64
# reward:-532.2574043273926, net return: -15.771713381611468
# Episode 	39, the episode reward is 	-2021.24
# reward:-608.5977973937988, net return: 2.204824036423692
# Episode 	40, the episode reward is 	-2266.37
# reward:-1563.9522399902417, net return: -8.054693788745421
# Episode 	41, the episode reward is 	-249.23
# reward:-520.4311561584473, net return: -18.336921579655407
# Episode 	42, the episode reward is 	-2130.60
# reward:45.94280242919922, net return: -9.528230182519636
# Episode 	43, the episode reward is 	-1292.14
# reward:-2137.7005767822266, net return: -11.890517557783499
# Episode 	44, the episode reward is 	-3393.10
# reward:135.5073471069336, net return: 1.1344150054386546
# Episode 	45, the episode reward is 	1286.02
# reward:-705.6302070617676, net return: 8.250730958435902
# Episode 	46, the episode reward is 	965.19
# reward:78.6544189453125, net return: 0.7888319688764831
# Episode 	47, the episode reward is 	2386.24
# reward:-1856.2734756469763, net return: 29.647179762610193
# Episode 	48, the episode reward is 	3202.00
# reward:-1356.4101867675818, net return: -9.681748720764519
# Episode 	49, the episode reward is 	-3049.34
# reward:-232.5504035949707, net return: 2.098109058792602
# Episode 	50, the episode reward is 	1932.05
# reward:-402.5913429260254, net return: 15.768272918541081
# Episode 	51, the episode reward is 	3994.31
# reward:-803.8397293090784, net return: 10.252880442313787
# Episode 	52, the episode reward is 	5173.89
# reward:-523.0625, net return: -12.494310164579922
# Episode 	53, the episode reward is 	-2311.40
# reward:23.687931060794654, net return: 21.373954992097076
# Episode 	54, the episode reward is 	3535.41
# reward:-939.7965202331543, net return: -15.958008341693148
# Episode 	55, the episode reward is 	-2537.37
# reward:-943.7869148254395, net return: -13.356777369391075
# Episode 	56, the episode reward is 	-2453.06
# reward:-1396.6004943847693, net return: -15.81660869470645
# Episode 	57, the episode reward is 	-2526.68
# reward:-406.3021354675293, net return: -16.390777515744297
# Episode 	58, the episode reward is 	-2373.05
# reward:523.4697952270508, net return: 0.4663502493187792
# Episode 	59, the episode reward is 	1048.82
# reward:-513.5973320007324, net return: -17.554170910809937
# Episode 	60, the episode reward is 	-2368.92
# reward:-959.7504463195801, net return: -16.47194152764329
# Episode 	61, the episode reward is 	-2136.06
# reward:-105.73023223876953, net return: -17.493829501816066
# Episode 	62, the episode reward is 	-2093.76
# reward:-451.97889709473384, net return: -10.712084733051986
# Episode 	63, the episode reward is 	-2403.52
# reward:-838.405590057373, net return: 6.420967760303773
# Episode 	64, the episode reward is 	2470.66
# reward:47.292999267578125, net return: -9.496226577401272
# Episode 	65, the episode reward is 	-762.57
# reward:-132.80878829956055, net return: -7.547501052426575
# Episode 	66, the episode reward is 	-2103.40
# reward:-634.4575004577637, net return: 5.0899199021089085
# Episode 	67, the episode reward is 	-2156.77
# reward:-706.7175369262695, net return: 8.70996697920464
# Episode 	68, the episode reward is 	1022.60
# reward:-2096.906150817871, net return: -9.193516560479766
# Episode 	69, the episode reward is 	-3723.99
# reward:-761.4873962402344, net return: -9.476240897457682
# Episode 	70, the episode reward is 	-2455.22
# reward:-36.47833633423579, net return: 2.440371784185345
# Episode 	71, the episode reward is 	2231.33
# reward:-1103.1322326660156, net return: -10.993932776041715
# Episode 	72, the episode reward is 	-2944.58
# reward:-71.53147506713867, net return: 2.6786480731859745
# Episode 	73, the episode reward is 	2186.23
# reward:-1563.9522399902417, net return: -8.054693788745421
# Episode 	74, the episode reward is 	-249.23
# reward:-410.07184982299805, net return: -14.77254221118232
# Episode 	75, the episode reward is 	-2177.02
# reward:-949.7744598388672, net return: -15.48811413426197
# Episode 	76, the episode reward is 	-2335.02
# reward:-731.2953338623047, net return: -14.698116440639605
# Episode 	77, the episode reward is 	-2032.71
# reward:-2292.7260360717773, net return: -4.4857272640893395
# Episode 	78, the episode reward is 	-2195.40
# reward:572.136157989502, net return: 9.198680784276235
# Episode 	79, the episode reward is 	3364.92
# reward:-734.0679550170898, net return: -12.724417663584425
# Episode 	80, the episode reward is 	-2258.23
# reward:-939.7965202331543, net return: -19.93481954933413
# Episode 	81, the episode reward is 	-2524.76
# reward:-522.7084465026855, net return: -16.703519069824424
# Episode 	82, the episode reward is 	-2042.18
# reward:-513.5973320007324, net return: -16.005035998255195
# Episode 	83, the episode reward is 	-2342.73
# reward:-502.5085945129358, net return: -7.055045309260263
# Episode 	84, the episode reward is 	-2283.33
# reward:-514.7359771728516, net return: -11.77676619636383
# Episode 	85, the episode reward is 	-2339.17
# reward:-1928.19431304932, net return: 29.595843259054117
# Episode 	86, the episode reward is 	7507.72
# reward:-771.2496795654297, net return: -7.558617089692424
# Episode 	87, the episode reward is 	-2206.24
# reward:44.59455871582031, net return: -18.036700811550762
# Episode 	88, the episode reward is 	-1861.51
# reward:-638.1678924560547, net return: 4.0258046961313845
# Episode 	89, the episode reward is 	-2075.66
# reward:-660.3972244262695, net return: -9.667584298918168
# Episode 	90, the episode reward is 	-2270.15
# reward:-1643.6560554504395, net return: -1.6916844540013418
# Episode 	91, the episode reward is 	-2229.77
# reward:-660.3972244262695, net return: -9.667584298918168
# Episode 	92, the episode reward is 	-2270.15
# reward:-68.95330810547603, net return: 18.237941305503128
# Episode 	93, the episode reward is 	4856.28
# reward:-1034.7277507781982, net return: -4.6919353884212915
# Episode 	94, the episode reward is 	-2513.69
# reward:-773.6326942443811, net return: -5.599545944072947
# Episode 	95, the episode reward is 	-2087.91
# reward:-600.5432815551758, net return: -0.4006344914132889
# Episode 	96, the episode reward is 	-2515.84
# reward:-265.12300872802734, net return: 15.707911994316754
# Episode 	97, the episode reward is 	3383.50
# reward:-797.2854080200195, net return: 13.620367855685924
# Episode 	98, the episode reward is 	-898.74
# reward:-2096.906150817871, net return: -9.193516560479766
# Episode 	99, the episode reward is 	-3723.99

# %%
len(SP_return)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 20

# %%
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

def test_plots(baseline_df, portfolio_return, SP_return, dates):

    # Convert date strings to datetime objects
    dates = [datetime.strptime(date_str, '%Y-%m-%d') for date_str in dates]

    fig, axs = plt.subplots(1, 2, figsize=(12, 6))  # 1 row, 2 columns

    # Plotting the first subplot
    axs[0].plot_date(dates, portfolio_return, '-', label='Portfolio')
    axs[0].plot_date(dates, baseline_df['Value'], '-', label='Baseline')

    # Add title and labels
    axs[0].set_title('Percentage Return of Portfolio vs Baseline')
    axs[0].set_xlabel('Date')
    axs[0].set_ylabel('Percentage Return')
    axs[0].legend()
    axs[0].grid(True)

    # Plotting the second subplot
    axs[1].plot_date(dates, portfolio_return, '-', label='Portfolio')
    axs[1].plot_date(dates, SP_return, '-', label='SP500')
    axs[1].set_title('Percentage Return of Portfolio vs. SP500')
    axs[1].set_xlabel('Date')
    axs[1].set_ylabel('Percentage Return')
    axs[1].legend()
    axs[1].grid(True)

    # Adjust layout to prevent overlap
    plt.tight_layout()

    # Show plot
    plt.show()

# %%
from scipy.stats import norm
sns.set(style="whitegrid")




# Create histogram
sns.histplot(net_return_list, bins = 30 , kde=True, color='orange', edgecolor='black')
mu, std = norm.fit(net_return_list)

# Plot fitted normal distribution
plt.text(0.75, 0.95, f'Mean: {mu:.2f}\nStd: {std:.2f}', transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.5))



# Customize labels and title
plt.xlabel('Return', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
#plt.title('Histogram of Data', fontsize=16)




# Show plot
plt.show()

# %%
sns.set(style="whitegrid")
data = net_return_portfolio_list
# Create histogram
sns.histplot(data, bins = 30 , kde=True, color='skyblue', edgecolor='black')
mu, std = norm.fit(data)

# Plot fitted normal distribution
plt.text(0.75, 0.95, f'Mean: {mu:.2f}\nStd: {std:.2f}', transform=plt.gca().transAxes,
        fontsize=10, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.5))


# Customize labels and title
plt.xlabel('Perid Percentage Return', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
#plt.title('Return Distribution', fontsize=16)
plt.legend()



# Show plot
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.set(style="whitegrid")
data = net_return_SP_list
# Create histogram
sns.histplot(data, bins = 30 , kde=True, color='skyblue', edgecolor='black')
mu, std = norm.fit(data)

# Plot fitted normal distribution
plt.text(0.75, 0.95, f'Mean: {mu:.2f}\nStd: {std:.2f}', transform=plt.gca().transAxes,
        fontsize=10, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.5))


# Customize labels and title
plt.xlabel('Perid Percentage Return', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
#plt.title('Return Distribution', fontsize=16)
plt.legend()



# Show plot
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
len(portfolio_return)
percentage_return_portfolio = (portfolio_return - portfolio_return[0]) / portfolio_return[0] * 100
SP_return = np.array(SP_return, dtype=np.float64)
percentage_return_SP500 = (SP_return - SP_return[0]) / SP_return[0] * 100

plt.plot(percentage_return_portfolio, label='Portfolio')
plt.plot(percentage_return_SP500, label='SP500')

# Add title and labels
plt.title('Percentage Return of Portfolio')
plt.xlabel('Date')
plt.ylabel('Percentage Return')

# Show legend
plt.legend()

# Show grid
plt.grid(True)

# Show plot
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# First plot

baseline_df['Value'][0]
percentage_return_portfolio = (portfolio_return - portfolio_return[0]) / portfolio_return[0] * 100
percentage_return_baseline = (baseline_df['Value'] - baseline_df['Value'][0]) / baseline_df['Value'][0] * 100

fig, axs = plt.subplots(1, 2, figsize=(12, 6))  # 1 row, 2 columns
axs[0].plot(percentage_return_portfolio, label='Portfolio')
axs[0].plot(percentage_return_SP500, label='SP500')
axs[0].set_title('Percentage Return of Portfolio vs. SP500')
axs[0].set_xlabel('Date')
axs[0].set_ylabel('Percentage Return')
axs[0].legend()
axs[0].grid(True)

# Second plot

percentage_return_portfolio = (portfolio_return - portfolio_return[0]) / portfolio_return[0] * 100
SP_return = np.array(SP_return, dtype=np.float64)
percentage_return_SP500 = (SP_return - SP_return[0]) / SP_return[0] * 100
axs[1].plot(percentage_return_portfolio, label='Portfolio')
axs[1].plot(percentage_return_baseline, label='Baseline')
axs[1].set_title('Percentage Return of Portfolio vs. Baseline')
axs[1].set_xlabel('Date')
axs[1].set_ylabel('Percentage Return')
axs[1].legend()
axs[1].grid(True)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show plots
plt.show()

# %%
plt.plot(reward_list)

# %%
np.median(reward_list)
# Out:
# 18.13530731201172

# %%
np.mean(reward_list)
# Out:
# -6.641378084025778

# %%
np.std(reward_list)
# Out:
# 661.4488581239503

# %%
sns.distplot(reward_list)
# Out:
# <Axes: ylabel='Density'>

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# PLOTS

# %%
def standardize_stock(stock):
  mean = stock.mean()
  std_dev = stock.std()
  standardized_values = (stock - mean) / std_dev

  return standardized_values


standardized_AAPL = standardize_stock( stock_d['AAPL']['adj close'])
standardized_XOM = standardize_stock(stock_d['XOM']['adj close'])
standardized_UNH = standardize_stock(stock_d['UNH']['adj close'])
standardized_PG = standardize_stock(stock_d['PG']['adj close'])
standardized_JPM = standardize_stock(stock_d['JPM']['adj close'])
standardized_GSPC = standardize_stock(stock_d['^GSPC']['adj close'])



standardized_AAPL.plot(label='Stock AAPL')
#standardized_XOM.plot(label='Stock XOM')
standardized_GSPC.plot(label='S&P')
#standardized_PG.plot(label='PG')
#standardized_UNH.plot(label='UNH')
'''
stock_d['UNH']['adj close'].plot(label='Stock UNH')
stock_d['PG']['adj close'].plot(label='Stock PG')
stock_d['JPM']['adj close'].plot(label='Stock JPM')
(stock_d['^GSPC']['adj close']/10).plot(label='S&P')'''

# Add title and labels
plt.title('Stock Prices Comparison')
plt.xlabel('Date')
plt.ylabel('Price')

# Show legend
plt.legend()

# Show grid
plt.grid(True)

# Show plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-a99181eeedf3> in <cell line: 10>()
#       8
#       9 standardized_AAPL = standardize_stock( stock_d['AAPL']['adj close'])
# ---> 10 standardized_XOM = standardize_stock(stock_d['XOM']['adj close'])
#      11 standardized_UNH = standardize_stock(stock_d['UNH']['adj close'])
#      12 standardized_PG = standardize_stock(stock_d['PG']['adj close'])
#
# KeyError: 'XOM'

# %%
stock_d['UNH']

# %%
percentage_return_UNH = (stock_d['UNH']['adj close'] - stock_d['UNH']['adj close'].iloc[0]) / stock_d['UNH']['adj close'].iloc[0] * 100
percentage_return_UNH.index = stock_d['UNH']['Date']
percentage_return_SP500 = (stock_d['^GSPC']['adj close'] - stock_d['^GSPC']['adj close'].iloc[0]) / stock_d['^GSPC']['adj close'].iloc[0] * 100
percentage_return_SP500.index = stock_d['UNH']['Date']
percentage_return_PG = (stock_d['PG']['adj close'] - stock_d['PG']['adj close'].iloc[0]) / stock_d['PG']['adj close'].iloc[0] * 100
percentage_return_PG.index = stock_d['UNH']['Date']
percentage_return_AAPL = (stock_d['AAPL']['adj close'] - stock_d['AAPL']['adj close'].iloc[0]) / stock_d['AAPL']['adj close'].iloc[0] * 100
percentage_return_AAPL.index = stock_d['UNH']['Date']
percentage_return_XOM = (stock_d['XOM']['adj close'] - stock_d['XOM']['adj close'].iloc[0]) / stock_d['XOM']['adj close'].iloc[0] * 100
percentage_return_XOM.index = stock_d['UNH']['Date']
percentage_return_JPM = (stock_d['JPM']['adj close'] - stock_d['JPM']['adj close'].iloc[0]) / stock_d['JPM']['adj close'].iloc[0] * 100
percentage_return_JPM.index = stock_d['UNH']['Date']

# %%
import matplotlib.dates as mdates

percentage_return_UNH = (stock_d['UNH']['adj close'] - stock_d['UNH']['adj close'].iloc[0]) / stock_d['UNH']['adj close'].iloc[0] * 100
percentage_return_UNH.index = stock_d['UNH']['Date']
percentage_return_SP500 = (stock_d['^GSPC']['adj close'] - stock_d['^GSPC']['adj close'].iloc[0]) / stock_d['^GSPC']['adj close'].iloc[0] * 100
percentage_return_SP500.index = stock_d['UNH']['Date']
percentage_return_PG = (stock_d['PG']['adj close'] - stock_d['PG']['adj close'].iloc[0]) / stock_d['PG']['adj close'].iloc[0] * 100
percentage_return_PG.index = stock_d['UNH']['Date']
percentage_return_AAPL = (stock_d['AAPL']['adj close'] - stock_d['AAPL']['adj close'].iloc[0]) / stock_d['AAPL']['adj close'].iloc[0] * 100
percentage_return_AAPL.index = stock_d['UNH']['Date']
percentage_return_XOM = (stock_d['XOM']['adj close'] - stock_d['XOM']['adj close'].iloc[0]) / stock_d['XOM']['adj close'].iloc[0] * 100
percentage_return_XOM.index = stock_d['UNH']['Date']
percentage_return_JPM = (stock_d['JPM']['adj close'] - stock_d['JPM']['adj close'].iloc[0]) / stock_d['JPM']['adj close'].iloc[0] * 100
percentage_return_JPM.index = stock_d['UNH']['Date']

# Create a figure and axis object
# Create a figure and axis object

fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
ax.plot(percentage_return_UNH.index, percentage_return_SP500.values, color='black', linewidth=2,  linestyle='--', label = 'SP500')
ax.plot(percentage_return_UNH.index, percentage_return_UNH.values, color='navy', linewidth=1.5, label = ' UNH')

ax.plot(percentage_return_UNH.index, percentage_return_PG.values, color='limegreen', linewidth=1.5, label = 'PG')
ax.plot(percentage_return_UNH.index, percentage_return_AAPL.values, color='skyblue', linewidth=1.5, label = 'AAPL')
ax.plot(percentage_return_UNH.index, percentage_return_XOM.values, color='Purple', linewidth=1.5, label = 'XOM')
ax.plot(percentage_return_UNH.index, percentage_return_JPM.values, color='Sienna', linewidth=1.5, label = 'JPM')


# Set x-axis label
ax.set_xlabel('Date')

# Get the last observation date and value
last_observation_date = percentage_return_SP500.index[-1]
last_observation_value = percentage_return_SP500.values[-1]

# Add the last observation to the plot
ax.scatter(last_observation_date, last_observation_value, color='red', label=f'Last Observation: {last_observation_date}', zorder=5)

# Set y-axis label
ax.set_ylabel('Percentage Return')

# Add gridlines
ax.grid(True)

# Set x-axis ticks to show only the year
ax.xaxis.set_major_locator(plt.MaxNLocator(integer=True))
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
ax.plot(percentage_return_UNH.index, percentage_return_SP500.values, color='black', linewidth=2, linestyle='--', label='SP500')
ax.plot(percentage_return_UNH.index, percentage_return_UNH.values, color='navy', linewidth=1.5, label='UNH')
ax.plot(percentage_return_UNH.index, percentage_return_PG.values, color='limegreen', linewidth=1.5, label='PG')
ax.plot(percentage_return_UNH.index, percentage_return_AAPL.values, color='skyblue', linewidth=1.5, label='AAPL')
ax.plot(percentage_return_UNH.index, percentage_return_XOM.values, color='Purple', linewidth=1.5, label='XOM')
ax.plot(percentage_return_UNH.index, percentage_return_JPM.values, color='Sienna', linewidth=1.5, label='JPM')

# Set x-axis label
ax.set_xlabel('Date')

# Get the last observation date and value
last_observation_date = percentage_return_SP500.index[-1]
last_observation_value = percentage_return_SP500.values[-1]

# Add the last observation to the plot
ax.scatter(last_observation_date, last_observation_value, color='red', label=f'Last Observation: {last_observation_date}', zorder=5)

# Add a vertical line at the specified date
ax.axvline(x='2022-01-04', color='gray', linestyle='--', linewidth=2, label='Start testing period')

# Set y-axis label
ax.set_ylabel('Percentage Return')

# Add gridlines
ax.grid(True)

# Set x-axis ticks to show only the year
ax.xaxis.set_major_locator(plt.MaxNLocator(integer=True))
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.legend()
plt.show()

# %%
env.env['AAPL']

# %%
from matplotlib.dates import YearLocator, DateFormatter
percentage_return_UNH = (stock_d['UNH']['adj close'] - stock_d['UNH']['adj close'].iloc[0]) / stock_d['UNH']['adj close'].iloc[0] * 100
percentage_return_SP500 = (stock_d['^GSPC']['adj close'] - stock_d['^GSPC']['adj close'].iloc[0]) / stock_d['^GSPC']['adj close'].iloc[0] * 100
percentage_return_PG = (stock_d['PG']['adj close'] - stock_d['PG']['adj close'].iloc[0]) / stock_d['PG']['adj close'].iloc[0] * 100
percentage_return_AAPL = (stock_d['AAPL']['adj close'] - stock_d['AAPL']['adj close'].iloc[0]) / stock_d['AAPL']['adj close'].iloc[0] * 100
percentage_return_XOM = (stock_d['XOM']['adj close'] - stock_d['XOM']['adj close'].iloc[0]) / stock_d['XOM']['adj close'].iloc[0] * 100

start_date = pd.to_datetime('2014-07-22')  # Example start date
end_date = pd.to_datetime('2024-01-12')    # Example end date
dates = pd.date_range(start=start_date, end=end_date, freq='D')

prices_series = pd.Series(percentage_return_UNH, index=pd.date_range(start_date, end_date))
'''
percentage_return_UNH.plot(label='Stock UNH')
percentage_return_SP500.plot(label='Stock SP500')
percentage_return_PG.plot(label='PG')
percentage_return_AAPL.plot(label='AAPL')
percentage_return_XOM.plot(label='XOM')'''

plt.xticks(rotation=45, ha='right')  # Rotate and right-align x-axis labels for better readability
plt.gca().xaxis.set_major_locator(YearLocator())  # Set major ticks to occur every year
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y'))  # Format major ticks to show year only

# Add labels and title
plt.xlabel("Year")
plt.ylabel("Stock Price")
plt.title("Stock Prices Over Time")

plt.grid(True)  # Add grid lines for better readability
plt.show()
